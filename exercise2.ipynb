# %% [markdown]
# # Exercise 2: Data Processing and Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

try:
    import otter
    grader = otter.Notebook() ## setting a grader for specific notebook

except:

    # %pip install otter-grader ## install otter-grader
    import otter
    grader = otter.Notebook()
"""
try:
    from gofer.ok import check
except:
    # %pip install git+https://github.com/grading/gradememaybe.git
    from gofer.ok import check
"""
# Out:
# '\ntry:\n    from gofer.ok import check\nexcept:\n    %pip install git+https://github.com/grading/gradememaybe.git\n    from gofer.ok import check\n'

# %% [markdown]
# Today we're working with simulated smartwatch health data. You'll notice when you read in the csv file that we have 7 columns: User ID, Heart Rate (BPM), Blood Oxygen Level (%), Step Count, Sleep Duration (hours), Activity Level, and Stress Level. We're going to go through and "clean up" the data so that we can calculate some basic statistics such as mean, median, minimum, and maximum for each variable. Run the cell below to read in the table saving it in the variable `smartwatch`.

# %%
smartwatch = pd.read_csv("unclean_smartwatch_health_data.csv")
smartwatch
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1         NaN               NaN               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# 4      2130.0         61.950165               98.583797  15679.067648
# ...       ...               ...                     ...           ...
# 9995   1524.0         78.819386               98.931927   2948.491953
# 9996   4879.0         48.632659               95.773035   4725.623070
# 9997   2624.0         73.834442               97.945874   2571.492060
# 9998   4907.0               NaN               98.401058   3364.788855
# 9999   4113.0         70.063864               98.475606    544.696104
#
#      Sleep Duration (hours) Activity Level Stress Level
# 0         7.167235622316564  Highly Active            1
# 1         6.538239375570314  Highly_Active            5
# 2                     ERROR  Highly Active            5
# 3         7.367789630207228          Actve            3
# 4                       NaN  Highly_Active            6
# ...                     ...            ...          ...
# 9995      7.402748595032027         Active            7
# 9996     6.3821659358529015      Sedentary            2
# 9997       6.91654920303435      Sedentary            4
# 9998      5.691233932149209         Active            8
# 9999      5.691001039740254          Actve            5
#
# [10000 rows x 7 columns]

# %% [markdown]
# Let's start together with the Heart Rate column. Just looking at the preview table above we can see two things right away: (1) we have `NaN` values meaning data was not collected for those individuals, and (2) some of the heart rate values are abnormally high i.e. `247.803052`. Let's see what the entire range of values look like.

# %%
print(smartwatch['Heart Rate (BPM)'].min(), smartwatch['Heart Rate (BPM)'].max())
# Out:
# 40.0 296.5939695131042

# %% [markdown]
# **Question 1**: Set the variables below equal to the minimum heart rate and the maximum heart rate in the dataset. This is just practice for the method of checking answers as you go. Afterwards run the cell below to check your answer.

# %%
minimumHeartRate = float(smartwatch['Heart Rate (BPM)'].min())
maximumHeartRate = float(smartwatch['Heart Rate (BPM)'].max())

minimumHeartRate, maximumHeartRate
# Out:
# (40.0, 296.5939695131042)

# %%
grader.check('q1')
# Out:
# Question 1 results: All test cases passed!

# %% [markdown]
# Notice that the maximum value of `296` beats per minimute is WAY above normal range of heart rates. In fact, according to [heart.org](https://www.heart.org/en/healthy-living/fitness/fitness-basics/target-heart-rates) the highest estimated heart rate based on age ranges from 150 to 200 for adults. This will vary between individuals, but this is a good starting point for us to think about outliers in the heart rate values in this dataset. Let's see how many rows have missing data or heart rates above 200.

# %%
## select rows where Heart Rate is NaN or rows where the heart rate is above 200. 
# Emphasis on the usage of 'or' here, we want rows where either 
# scenario 1 (NaN) OR scenario 2 (>200) is true. 

outlierHeartRaterows = smartwatch[smartwatch['Heart Rate (BPM)'] > 200]
nullHeartRaterows = smartwatch[smartwatch['Heart Rate (BPM)'].isnull()]

print(len(outlierHeartRaterows) + len(nullHeartRaterows))
# Out:
# 450

# %%
## Now let's get a table of all the other rows. 
heartrateRows = smartwatch[(~smartwatch['Heart Rate (BPM)'].isnull()) & (smartwatch['Heart Rate (BPM)'] <= 200)]

print(heartrateRows)
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 3      2294.0         40.000000               96.894213  13797.338044
# 4      2130.0         61.950165               98.583797  15679.067648
# 5      2095.0         96.285938               94.202910  10205.992256
# 6      4772.0         47.272257               95.389760   3208.781177
# ...       ...               ...                     ...           ...
# 9994   1942.0         77.912299               98.640583  10061.145291
# 9995   1524.0         78.819386               98.931927   2948.491953
# 9996   4879.0         48.632659               95.773035   4725.623070
# 9997   2624.0         73.834442               97.945874   2571.492060
# 9999   4113.0         70.063864               98.475606    544.696104
#
#      Sleep Duration (hours) Activity Level Stress Level
# 0         7.167235622316564  Highly Active            1
# 3         7.367789630207228          Actve            3
# 4                       NaN  Highly_Active            6
# 5         8.378342673824589  Highly_Active           10
# 6         7.871146008904113     Seddentary            2
# ...                     ...            ...          ...
# 9994      5.428634630125767     Seddentary           10
# 9995      7.402748595032027         Active            7
# 9996     6.3821659358529015      Sedentary            2
# 9997       6.91654920303435      Sedentary            4
# 9999      5.691001039740254          Actve            5
#
# [9550 rows x 7 columns]

# %% [markdown]
# **Question 2:**
#
# Notice here that the length of the two tables (`450` and `9550`) add up to the total number rows (`n=10000`). This is a good sanity check as we manipulate the table. Now we have to decide how we deal with these missing values and outliers. One method to do this would be remove all the rows with null values or outlier values. Another method is use imputation - this can be done in several ways but below we're going to substitute the average heart rate for the missing and mismeasured values. Do we think this will change the mean?

# %%
HeartRateMean = float(heartrateRows['Heart Rate (BPM)'].mean())
print(HeartRateMean)
# Out:
# 75.13268404820141

# %%
outlierHeartRaterows['Heart Rate (BPM)'] = HeartRateMean
nullHeartRaterows['Heart Rate (BPM)'] = HeartRateMean


print(outlierHeartRaterows)
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 2      1860.0         75.132684               97.052954   2826.521994
# 337    2369.0         75.132684               95.441773   2998.761919
# 393    2443.0         75.132684               95.497181   1227.804688
# 403    3200.0         75.132684               96.011492   9402.746140
# 595    2129.0         75.132684               97.161853   2555.402184
# 649    2008.0         75.132684               98.356789   2739.171166
# 818    3156.0         75.132684                     NaN   7281.778831
# 1195   3261.0         75.132684               99.652006   2867.872064
# 1391   4621.0         75.132684               96.688083  20577.677290
# 1602   4737.0         75.132684               95.095839  16072.283561
# 2023      NaN         75.132684               99.032130  17620.765455
# 2211   2711.0         75.132684               97.852781   1786.998129
# 2212   4020.0         75.132684               95.280955   3794.430590
# 2338   1762.0         75.132684               96.026123   9969.240744
# 2454   4902.0         75.132684               97.092166  11843.255005
# 3113   1035.0         75.132684               94.120618   5303.010562
# 3235   4478.0         75.132684               97.295126   2402.047207
# 3354   4976.0         75.132684               96.703748   4265.937611
# 3451   2768.0         75.132684               96.761963   4723.116194
# 3886   3856.0         75.132684               96.440489    841.196042
# 3983   1597.0         75.132684               99.396872  23860.187292
# 4146   1574.0         75.132684               98.386439   4255.759517
# 4185   4643.0         75.132684               95.415588  54698.646371
# 4254   3563.0         75.132684               95.768379   5871.602913
# 4275   1844.0         75.132684               97.847790   1855.481139
# 4366   2655.0         75.132684              100.000000  11331.922879
# 4509   4642.0         75.132684               97.983060   8526.218347
# 4521   4629.0         75.132684              100.000000   5614.112857
# 4780   2003.0         75.132684               98.242375   5299.159731
# 4792   3530.0         75.132684               99.960103   5396.348537
# 4833   4829.0         75.132684               97.920202  17207.114700
# 5090   4797.0         75.132684               98.647925   2604.794451
# 5170   2023.0         75.132684               94.316370    789.259057
# 5265   3277.0         75.132684              100.000000  10180.369091
# 5870   1499.0         75.132684               96.833301           NaN
# 6135   1389.0         75.132684               96.558205   2240.873043
# 6376   3218.0         75.132684               98.446205   8287.695252
# 6726   2338.0         75.132684               95.948327   3935.287388
# 6974   1935.0         75.132684               94.263021  25043.512031
# 7897   3488.0         75.132684               93.422300   1167.050964
# 8369   2283.0         75.132684                     NaN  21495.639335
# 8471   2706.0         75.132684               96.239663  19209.243829
# 8692   1698.0         75.132684               96.382266   3225.230149
# 8895   3294.0         75.132684              100.000000  18039.603487
# 8997      NaN         75.132684               96.643436   4226.877196
# 9164   3381.0         75.132684               98.982453   5247.004522
# 9438   4411.0         75.132684               99.524016  11209.020829
# 9654   2898.0         75.132684               96.082553     45.956119
# 9665   2069.0         75.132684               96.509094   5002.019249
# 9752   4683.0         75.132684               97.371766   5759.938203
#
#      Sleep Duration (hours) Activity Level Stress Level
# 2                     ERROR  Highly Active            5
# 337       6.670622263019579  Highly Active            9
# 393       5.185244686595328  Highly_Active            9
# 403       7.190062873693008  Highly_Active            9
# 595       5.928628388578222  Highly Active            7
# 649       7.272009723254014  Highly_Active          NaN
# 818       4.300171191258864      Sedentary            3
# 1195      7.218530947169898         Active            7
# 1391      8.049854248644627         Active            3
# 1602       6.98847026102848          Actve            6
# 2023      7.641814526532746      Sedentary          NaN
# 2211      9.403363125752087         Active            5
# 2212      9.471210427832666     Seddentary            2
# 2338      7.434143975499938      Sedentary            4
# 2454     4.8230739165423175      Sedentary            5
# 3113      5.216491298730846         Active            4
# 3235       8.40664811517765     Seddentary            3
# 3354      6.272040953618372     Seddentary            4
# 3451      7.656776835132766  Highly Active            3
# 3886        8.5141016110168     Seddentary            7
# 3983       9.72770039263133  Highly Active           10
# 4146      9.950312577595927      Sedentary            1
# 4185        8.4611474189254            NaN           10
# 4254      6.169674782300074          Actve            3
# 4275      7.103458436811003      Sedentary            5
# 4366      6.252116628792069          Actve            8
# 4509      7.157804627096766  Highly Active            1
# 4521      6.304731924019175         Active            2
# 4780      8.471284845728434         Active            1
# 4792       5.03699852197675          Actve            4
# 4833       5.93139606422032  Highly_Active            3
# 5090      4.604169369845159  Highly Active            1
# 5170      4.456316515329178            NaN            6
# 5265      5.234907365011507      Sedentary            1
# 5870      7.221605491090915      Sedentary            9
# 6135      6.249638938845372  Highly_Active            7
# 6376      4.174557486059257  Highly Active           10
# 6726      9.145513040749627      Sedentary            1
# 6974      5.452934114413052  Highly_Active            6
# 7897     6.3843230507913775          Actve            7
# 8369      5.291653956497481  Highly_Active            2
# 8471       7.26153538491556          Actve            9
# 8692      6.801618776704774     Seddentary            6
# 8895      7.064974772457126         Active            9
# 8997     5.2023674086270795  Highly_Active            3
# 9164      9.026252817225515  Highly Active            6
# 9438                  ERROR  Highly Active            3
# 9654       5.63988977577483         Active            3
# 9665       7.82197109767565     Seddentary            2
# 9752      5.496136294267198      Sedentary            9
# /tmp/ipykernel_37784/936369900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outlierHeartRaterows['Heart Rate (BPM)'] = HeartRateMean
# /tmp/ipykernel_37784/936369900.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nullHeartRaterows['Heart Rate (BPM)'] = HeartRateMean

# %%
smartwatch_hr = pd.concat([outlierHeartRaterows, nullHeartRaterows, heartrateRows])

fullTableHRMean = float(smartwatch_hr['Heart Rate (BPM)'].mean())

print(fullTableHRMean)
# Out:
# 75.13268404820141

# %%
grader.check('q2')
# Out:
# Question 2 results: All test cases passed!

# %% [markdown]
# Notice how the mean doesn't change when you use the imputed mean as the substituted values. However, as a note this will change the distribution of values and has the potential to obscure the causes of missing values or outliers.

# %%
sns.histplot(smartwatch['Heart Rate (BPM)'], label ='With Missing Values and Outliers')
sns.histplot(smartwatch_hr['Heart Rate (BPM)'], label = 'With Mean as Imputed Value')
plt.legend()

# %% [markdown]
# **Question 3**: How does the imputation method affect the median values?  Remember the table `smartwatch` remains unchanged and can be used to find the original median value.
#
# ANSWER:
# There's very small change which rounds off to 0.1 as change. There isn't big change.

# %%
## coding cell to check the difference in median values 

original_median = smartwatch['Heart Rate (BPM)'].median()
imputed_median = smartwatch_hr['Heart Rate (BPM)'].median()

print(original_median)
print(imputed_median)
difference = original_median - imputed_median
print(difference)
# Out:
# 75.22060125775644
# 75.13268404820141
# 0.08791720955503024

# %% [markdown]
# Now let's repeat this process for the other columns as well.
#
# **Question 4**: Find the minimum, maximum, and mean Blood Oxygen Level.

# %%
minBloodO2 = float(smartwatch['Blood Oxygen Level (%)'].min())

maxBloodO2 = float(smartwatch['Blood Oxygen Level (%)'].max())

meanBloodO2 = float(smartwatch['Blood Oxygen Level (%)'].mean())

minBloodO2, maxBloodO2, meanBloodO2
# Out:
# (90.79120814564097, 100.0, 97.84158102099076)

# %%
grader.check('q4')
# Out:
# Question 4 results: All test cases passed!

# %% [markdown]
# We can do some visualizations using a box plot to better decide if there's any outliers we'd like to remove. Maybe you decide that everything below 92.5 is an outlier should be removed or maybe you decide to keep all of the values or maybe you decide to remove all values under 94% since that falls outside of a normal, healthy range according to doctors (I would not suggest this last one as it would obscure quite a bit of data! But some analysts might consider it!). In question 5, you can make that decision and justify your answer.

# %%
sns.boxplot(smartwatch['Blood Oxygen Level (%)'])
# Out:
# <Axes: ylabel='Blood Oxygen Level (%)'>

# %% [markdown]
# **Question 5**: Decide how you want to deal with missing and outlier values in the Blood Oxygen Level column. Set your final table equal to the variable `smartwatch_o2`. Use the space below to explain your decisions.
#
# Notes: Refer to [this article](https://pmc.ncbi.nlm.nih.gov/articles/PMC5548942/) on methods of handling these type of instances in data. Keep in mind, you might find that either there are no missing values or no outliers. That's okay, just indicate that in the written space below and update the table i.e. `smartwatch_o2 = smartwatch_hr`
#
# ANSWER:
#
# I just went to check what might be normal highest level of blood oxygen and if it's higher than 92.5 , I erased it because I consider that as outlier. moreover, I also checked if there's null value and erased it if there's null value in blood oxygen level.

# %%
## use this space or additional cells to deal with the missing/outlier values. 
smartwatch_o2 = smartwatch[(~smartwatch['Blood Oxygen Level (%)'].isnull()) & (smartwatch['Blood Oxygen Level (%)'] >= 92.5)]


smartwatch_o2
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1         NaN               NaN               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# 4      2130.0         61.950165               98.583797  15679.067648
# ...       ...               ...                     ...           ...
# 9995   1524.0         78.819386               98.931927   2948.491953
# 9996   4879.0         48.632659               95.773035   4725.623070
# 9997   2624.0         73.834442               97.945874   2571.492060
# 9998   4907.0               NaN               98.401058   3364.788855
# 9999   4113.0         70.063864               98.475606    544.696104
#
#      Sleep Duration (hours) Activity Level Stress Level
# 0         7.167235622316564  Highly Active            1
# 1         6.538239375570314  Highly_Active            5
# 2                     ERROR  Highly Active            5
# 3         7.367789630207228          Actve            3
# 4                       NaN  Highly_Active            6
# ...                     ...            ...          ...
# 9995      7.402748595032027         Active            7
# 9996     6.3821659358529015      Sedentary            2
# 9997       6.91654920303435      Sedentary            4
# 9998      5.691233932149209         Active            8
# 9999      5.691001039740254          Actve            5
#
# [9673 rows x 7 columns]

# %% [markdown]
# Moving onto the Step Count column.
#
# **Question 6**: Find the minimum, maximum, and mean step counts.

# %%
minSteps = float(smartwatch['Step Count'].min())

maxSteps = float(smartwatch['Step Count'].max())

meanSteps = float(smartwatch['Step Count'].mean())

minSteps, maxSteps, meanSteps
# Out:
# (0.9101380609604088, 62486.690753464914, 6985.685884992229)

# %%
grader.check('q6')
# Out:
# Question 6 results: All test cases passed!

# %% [markdown]
# **Question 7**: Decide how you want to deal with missing and outlier values in the Steps column. Set your final table equal to the variable `smartwatch_steps`. Use the space below to explain your decisions.
#
# Notes: Refer to [this article](https://pmc.ncbi.nlm.nih.gov/articles/PMC5548942/) on methods of handling these type of instances in data. Keep in mind, you might find that either there are no missing values or no outliers. That's okay, just indicate that in the written space below and update the table i.e. `smartwatch_steps = smartwatch_o2`
#
# ANSWER:
#
# Here, I considered the steps as outliers if they're more than 20,000 and if they are null. Because in regular basis steps more than 20,000 is usually not adapted unless a person has foot travel work.

# %%
sns.boxplot(smartwatch['Step Count'])
# Out:
# <Axes: ylabel='Step Count'>

# %%
## use this space or additional cells to address the missing or outlier data. 

smartwatch_steps = smartwatch[(~smartwatch['Step Count'].isnull()) & (smartwatch['Step Count'] <= 20000)]

smartwatch_steps
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1         NaN               NaN               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# 4      2130.0         61.950165               98.583797  15679.067648
# ...       ...               ...                     ...           ...
# 9995   1524.0         78.819386               98.931927   2948.491953
# 9996   4879.0         48.632659               95.773035   4725.623070
# 9997   2624.0         73.834442               97.945874   2571.492060
# 9998   4907.0               NaN               98.401058   3364.788855
# 9999   4113.0         70.063864               98.475606    544.696104
#
#      Sleep Duration (hours) Activity Level Stress Level
# 0         7.167235622316564  Highly Active            1
# 1         6.538239375570314  Highly_Active            5
# 2                     ERROR  Highly Active            5
# 3         7.367789630207228          Actve            3
# 4                       NaN  Highly_Active            6
# ...                     ...            ...          ...
# 9995      7.402748595032027         Active            7
# 9996     6.3821659358529015      Sedentary            2
# 9997       6.91654920303435      Sedentary            4
# 9998      5.691233932149209         Active            8
# 9999      5.691001039740254          Actve            5
#
# [9357 rows x 7 columns]

# %% [markdown]
# Next onto the Sleep Duration column.
#
# **Question 8**: Try finding the minimum number of hours slept among participants.

# %%
minSleep = float(smartwatch['Sleep Duration (hours)'].min())

minSleep
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_37784/2622782591.py in <cell line: 0>()
# ----> 1 minSleep = float(smartwatch['Sleep Duration (hours)'].min())
#       2
#       3 minSleep
#
# ~/.local/lib/python3.12/site-packages/pandas/core/series.py in min(self, axis, skipna, numeric_only, **kwargs)
#    6505         **kwargs,
#    6506     ):
# -> 6507         return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#    6508
#    6509     @doc(make_doc("max", ndim=1))
#
# ~/.local/lib/python3.12/site-packages/pandas/core/generic.py in min(self, axis, skipna, numeric_only, **kwargs)
#   12386         **kwargs,
#   12387     ):
# > 12388         return self._stat_function(
#   12389             "min",
#   12390             nanops.nanmin,
#
# ~/.local/lib/python3.12/site-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379         )
#
# ~/.local/lib/python3.12/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6455                     "with non-numeric dtypes."
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#    6459     @Appender(make_doc("any", ndim=1))
#
# ~/.local/lib/python3.12/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     145                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#     149             return result
#
# ~/.local/lib/python3.12/site-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     402             mask = isna(values)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#     406         if datetimelike:
#
# ~/.local/lib/python3.12/site-packages/pandas/core/nanops.py in reduction(values, axis, skipna, mask)
#    1096             values, skipna, fill_value_typ=fill_value_typ, mask=mask
#    1097         )
# -> 1098         result = getattr(values, meth)(axis)
#    1099         result = _maybe_null_out(result, axis, mask, values.shape)
#    1100         return result
#
# ~/.local/lib/python3.12/site-packages/numpy/_core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      46 def _amin(a, axis=None, out=None, keepdims=False,
#      47           initial=_NoValue, where=True):
# ---> 48     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      49
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: '<=' not supported between instances of 'str' and 'float'

# %% [markdown]
# In the error message, you should see the phrase:
#
# `TypeError: '<=' not supported between instances of 'str' and 'float'`
#
# This means that the column is a combination of multiple data types. If you recall, we discussed computer readable data that columns HAVE to contain just a single data type. Having a combination of strings, characters, and numbers in a column will only cause more issues downstream. Let's try to figure out all the instances of non-numerical values in the column.
#
# First let's try to identify all the non-numerical values to make sure removing them doesn't obscure any important information.

# %%
for hours in smartwatch['Sleep Duration (hours)'].unique():  ## Loop through each unique item in the column
    try:
        numericVal = float('Sleep Duration (hours)')  ## first try to see if it can be converted to a number
    except ValueError:
        print(hours)  ## if it can't be converted print it to screen
# Out:
# 7.167235622316564
# 6.538239375570314
# ERROR
# 7.367789630207228
# nan
# 8.378342673824589
# 7.871146008904113
# 5.224139066195455
# 5.468413771417153
# 7.9544989905339145
# 7.541956463173237
# 4.830161671840198
# 5.814348465914493
# 6.269060283034982
# 6.444869604525839
# 6.392173806051382
# 7.848859015777246
# 6.718661172525927
# 6.621126995655419
# 5.3648491527683895
# 6.751333320225251
# 6.456918401449286
# 5.780212383241095
# 4.773999479227033
# 8.41542161341735
# 9.169583797303172
# 6.866753232803355
# 8.651900418719752
# 6.844302018581762
# 4.419708490039869
# 6.95044108406138
# 5.990742778206027
# 7.213770683599015
# 5.7399472789626955
# 7.081258685871372
# 7.791685704970522
# 8.531278990913485
# 7.978655960306142
# 4.827592494476892
# 4.825839792965481
# 7.647390482799075
# 5.923067990352865
# 5.024214580310577
# 8.282513944117321
# 5.945492567131957
# 8.945554951796462
# 5.83928648563342
# 5.379780644764782
# 6.403469797758008
# 7.637403648126468
# 6.93939597939567
# 9.337518118541205
# 6.757256406710402
# 6.2352107379111565
# 8.763732503534627
# 7.392793781685005
# 5.879630133172693
# 6.85791352875736
# 6.827247743905267
# 6.191851668087015
# 6.773624050574219
# 5.9659790984499725
# 7.146885698832684
# 5.707628633446368
# 5.1626892969962945
# 6.439034704731956
# 5.7909211045386755
# 4.516866155064028
# 4.554312521868752
# 6.635850437551147
# 6.971046408605005
# 6.052030514727384
# 4.229887888280923
# 5.188802886693731
# 6.017092237155613
# 7.154135026423208
# 3.877074076547937
# 3.0331901438352027
# 7.39682049463106
# 5.185877160562438
# 6.147988867222518
# 5.868158558451618
# 6.934494780867866
# 5.738883539240584
# 4.777099520399842
# 7.233968841889179
# 9.221594405490784
# 7.294682104834459
# 6.178609405931418
# 5.316882942475544
# 5.888655484250663
# 7.088511896845253
# 8.280848393722522
# 8.347840357315645
# 6.755557053735298
# 6.780194960726512
# 6.578324868497736
# 7.356516893585851
# 6.572139758559597
# 6.596702992213861
# 5.209658021888749
# 5.17396898272294
# 5.463284333002888
# 6.859884216816134
# 6.040399919060085
# 10.373567261347175
# 7.081894958676389
# 8.856211394753263
# 8.727118503133312
# 7.137004744087928
# 6.4387418991911245
# 5.151511516990889
# 5.597203452787953
# 7.760553060485513
# 6.904472998463502
# 5.5363251457819045
# 6.188868739068484
# 6.994175947492631
# 6.537212394657949
# 6.14274577608632
# 6.417811276247835
# 2.876708530364892
# 6.527310833422338
# 4.9125741606794975
# 7.0452135187462535
# 6.700942653968059
# 7.622609473868736
# 7.637279093784636
# 9.079469571860296
# 3.5252990125882064
# 6.310912758751652
# 3.439287691081752
# 7.236044873875793
# 6.249454675431915
# 5.793858376827125
# 6.900527747560983
# 4.92071693287113
# 6.1333751255786995
# 6.614799904858036
# 6.307210944457424
# 7.883614775842309
# 4.696693032339106
# 7.742313111452674
# 5.722153000379814
# 5.7352500324197315
# 7.819089459744227
# 6.0976959273196805
# 7.420672731221867
# 7.448680584772695
# 5.976296083423835
# 6.849409870193006
# 5.774156108593483
# 6.470651489160172
# 7.210528171310017
# 5.064869419306278
# 7.1604398353347145
# 4.266500725942315
# 5.380883658255592
# 5.462778122563456
# 5.833417505835631
# 5.066163249054267
# 7.9087393433335045
# 5.318184083631053
# 4.768744988189237
# 6.479991628045297
# 9.731299822824667
# 5.488131501454205
# 3.08756038228468
# 4.268778058259655
# 3.8263117567977587
# 7.125259327767962
# 6.646291719541397
# 6.825785787271773
# 8.18889568697907
# 8.943408350875643
# 7.764433702650757
# 7.6027899386011555
# 4.288912580313359
# 5.737108446097524
# 8.577232386961175
# 5.675509493666846
# 8.158331550105242
# 6.685071149386853
# 7.674778899633203
# 5.192240973327088
# 7.644700900619749
# 5.540783778974028
# 6.845818263476917
# 6.456353840543829
# 8.28805715452407
# 7.748108942640197
# 3.851434094768687
# 5.284399794605395
# 5.546161546930425
# 7.537609190324735
# 5.756958709255954
# 4.865952173453847
# 4.453028953662619
# 7.591030383062162
# 3.3896973033629685
# 8.082705695430972
# 4.569632159105675
# 5.828423437068083
# 4.747244645575727
# 5.121265137921359
# 6.164875694143121
# 4.18048162964046
# 5.891945395410191
# 6.654850175960306
# 7.201927707147318
# 3.4363723019945125
# 5.781740937390867
# 3.4195731170806924
# 5.737647903680929
# 5.854305801115332
# 7.443713844750055
# 7.960138195142298
# 4.967314685694361
# 6.941393558707121
# 7.4825163261372225
# 5.379426201444249
# 7.659508233956084
# 6.703951063176151
# 6.089815399849071
# 6.712643346138789
# 4.12969732447451
# 6.710695886778446
# 5.231294950506776
# 6.5432423081348325
# 5.891270361606108
# 6.932588320017508
# 8.2878040546915
# 6.690708383729154
# 8.000678574238497
# 4.965617825434963
# 8.650519801546139
# 4.9809033117447115
# 4.619842453664869
# 6.087754845734574
# 5.833310182953129
# 4.127010372564056
# 4.808233903821763
# 1.1086136901126222
# 4.47317008767848
# 5.51023958816301
# 8.734771438787751
# 7.569560060432488
# 6.985249957758299
# 9.747931492338019
# 3.8113712537147086
# 6.398450545295098
# 9.553163552265328
# 5.258330128100462
# 7.726007179079694
# 5.664921451739373
# 8.388950360490332
# 7.747236285834482
# 6.214264019717763
# 7.970859235883354
# 6.1466783954782915
# 6.699068563123942
# 7.3778645542752574
# 5.915694749772069
# 8.765432868819229
# 6.604977936316917
# 6.934471743375855
# 4.52541427377608
# 5.533187095483114
# 6.744326130189821
# 7.803102859787511
# 8.619396255538014
# 4.908980148216912
# 5.260072629398884
# 4.655226324116905
# 7.240419186558927
# 8.619994048068182
# 6.263040228574056
# 6.587561613388724
# 6.698795540632846
# 5.7963947985404705
# 4.668037558619413
# 8.089944185815268
# 6.7313797852991755
# 5.677729090219002
# 11.007690206138836
# 6.495746917345917
# 3.931969638631375
# 7.482213295004548
# 3.7376873048020935
# 7.199017778404964
# 7.159196759938225
# 8.569830220834548
# 4.996536701449671
# 6.059506321548279
# 6.396388806244134
# 7.798633988482986
# 7.151364486203832
# 7.278189135215216
# 8.328238982121865
# 6.166775540630666
# 8.694089344289967
# 6.367496384344239
# 7.843191656583698
# 5.756729164840463
# 7.392546637143738
# 8.237226710034687
# 4.876891512948527
# 7.9165247231180444
# 9.557593340315586
# 6.104159987016725
# 6.940241344743527
# 6.265889796784242
# 7.49426211291001
# 3.2251994561256536
# 4.384430886802476
# 7.50284754982229
# 6.539781019871101
# 3.4948123745338755
# 5.548902580482257
# 5.772357727665753
# 7.897333594924938
# 8.38454066366215
# 3.143186363957323
# 6.320777494229365
# 6.670622263019579
# 4.277555905832022
# 8.379675282695928
# 7.05647523573525
# 7.775770078778461
# 5.8313131909421285
# 5.331613056579806
# 5.645862299052107
# 6.334952824601891
# 5.861739392600007
# 7.858334594522809
# 10.49906566073934
# 7.373841466358962
# 3.579133029271691
# 6.7326082274188135
# 4.718301609759859
# 5.888491187644686
# 6.4465700064194165
# 6.111287725041643
# 4.947428894402029
# 7.282909255548166
# 3.5091680995849868
# 7.079535527359775
# 5.146944415247891
# 6.91804755830681
# 4.48297094741149
# 6.847237560439174
# 8.565970111370751
# 5.607966854707904
# 5.575068389841927
# 7.1487492069049505
# 4.427398757185029
# 8.161440688256556
# 7.713423426643104
# 8.423136080647023
# 7.318852228059259
# 9.331715368226089
# 3.691085280143967
# 8.785870623329153
# 5.915117938182273
# 5.68404653127135
# 5.428321542228138
# 7.2640257487939195
# 7.700364893614957
# 5.8004850421453495
# 6.910367040423186
# 10.645764905139025
# 5.495182715429429
# 5.908282125746762
# 8.629838481591595
# 4.136731249397264
# 6.867673807383509
# 2.8769016063044672
# 4.430748229280664
# 4.714884186406232
# 5.185244686595328
# 4.629202755682535
# 6.801474639294597
# 8.59976676688213
# 9.55858980689601
# 4.9558699105751
# 7.592640750686208
# 8.312756590032729
# 6.681383531360614
# 7.562736843404894
# 7.190062873693008
# 7.187799114637596
# 5.395046107760103
# 3.5091014813407746
# 5.9769645598759915
# 5.34969338458782
# 6.083184687235904
# 7.942176837947368
# 8.653512956561675
# 6.7260970630632855
# 4.723974793133707
# 5.916057635200159
# 5.341429479028939
# 6.685939322677909
# 5.799869689889252
# 7.8539934118447485
# 5.228067978814633
# 9.77514894856655
# 6.958574894586686
# 4.084188999912776
# 8.071840774130571
# 6.570324293984189
# 6.808630697803905
# 5.154115204050534
# 8.128927045584081
# 7.464264098582396
# 5.681877176980472
# 6.475165053219488
# 5.164515835588585
# 5.046277853772979
# 5.577039454771824
# 6.08907031030744
# 6.50262141988231
# 6.433513800146428
# 5.2022132887887125
# 7.6385620580813
# 7.870401582149371
# 7.5593104975224445
# 2.7461831945055044
# 5.002305864544564
# 4.267406762087337
# 3.8410345179685526
# 8.215865875953625
# 9.042711248069594
# 7.206994887280105
# 5.961069043330561
# 8.254532488123338
# 6.9200399391052185
# 5.717870695684265
# 7.343445079727398
# 6.793376680795596
# 7.539995163780452
# 12.140232872862926
# 9.17932181914528
# 6.725025399666523
# 5.090404222200121
# 3.119697256869867
# 8.426367171528689
# 8.179731903058912
# 5.55805725641502
# 6.368616078348943
# 6.812001358613616
# 7.391103425989748
# 8.981760464852645
# 4.545415430636883
# 7.510479294219383
# 6.828236528182412
# 5.734795907857717
# 7.709691097875732
# 6.333055950331835
# 6.379392919241842
# 6.970685346168697
# 5.81303719597394
# 7.481593546994852
# 5.90397330709016
# 9.035214560353776
# 6.842500601683245
# 5.494940281090253
# 6.96316471967328
# 7.984250955737493
# 4.137216605420402
# 8.400586640838291
# 7.010430540748135
# 6.454448317812807
# 5.470545287528129
# 7.0205786437063
# 5.174522194392308
# 3.516177325688708
# 5.430468934954143
# 6.091179398041944
# 7.4197147922805975
# 6.171793951765857
# 4.782359788169964
# 5.508342158376569
# 6.530959855482499
# 7.468395707125421
# 7.719777041294872
# 4.4570447659167165
# 6.576734643031471
# 7.660580839335819
# 5.190401396255423
# 9.200329588140814
# 5.758267510009601
# 8.029940815773237
# 7.536752991831565
# 5.468370505754391
# 6.524263501682174
# 8.546206808600758
# 5.694682809540513
# 6.76591461383464
# 4.241505220955036
# 7.039380390825302
# 5.893210842808426
# 7.285793051765919
# 5.233436994427638
# 6.9795814819916595
# 5.974628225812252
# 2.543125916526708
# 8.391614194101457
# 4.8553418848298175
# 5.533159612561786
# 8.48802060011029
# 7.334723931388879
# 6.0066200523672535
# 6.943644621121176
# 5.561494356403591
# 10.207205823118581
# 7.830300996368457
# 9.063211053996529
# 6.637870154301945
# 4.589247079624121
# 7.255007991647504
# 8.382668397997998
# 8.445700592680172
# 3.9685071807997065
# 5.6211449408879774
# 7.378131632857535
# 8.497079045401339
# 6.833725883961385
# 4.778381346608084
# 7.399056152566187
# 5.2236928423274716
# 6.061518155654656
# 6.635660877271784
# 5.495217706611081
# 7.454676287038913
# 7.628687383267091
# 8.042278910123132
# 8.637998651342457
# 4.659567121161923
# 4.804171946802947
# 9.102739112901306
# 8.922934654402546
# 8.507548328469616
# 5.621740213596107
# 9.032156508379234
# 6.245473864914585
# 7.014614874771402
# 8.391825569034259
# 7.311845100625552
# 8.562515946688682
# 6.519925917309197
# 6.195690500504311
# 6.019490862396862
# 4.775940020691342
# 2.302539358236169
# 8.062137544476865
# 6.148828246839772
# 7.397418681558379
# 6.73714318636212
# 7.916725303123822
# 8.107258041919664
# 5.072416809026272
# 8.79939420999062
# 7.796547163597244
# 5.186616198642542
# 5.526169416669925
# 4.635697767400901
# 7.441712555251841
# 6.23472192124303
# 2.760674815288893
# 5.668537637519964
# 5.928628388578222
# 6.658510166087957
# 4.1912361940199325
# 6.674976590630971
# 8.751100781593573
# 6.780511338064948
# 7.384173446276812
# 8.845075869051495
# 6.358184719715759
# 6.309778374974697
# 7.017279149797347
# 5.1727181371865
# 5.458159854663162
# 3.4411970511875207
# 9.932517880577583
# 7.7460532301461456
# 5.0790042920941305
# 8.03578576765195
# 5.287930401153586
# 6.602083663832942
# 6.594477144078191
# 5.830736476568704
# 5.28075703945781
# 8.31282152593471
# 6.626744053962054
# 9.02289941216286
# 4.938571903588187
# 5.790775779093288
# 6.431477727529356
# 8.1548161845922
# 5.316181581621833
# 7.356938086844615
# 7.014375820400543
# 8.642668258430664
# 7.2469592973064145
# 3.8055156537239583
# 4.979128470869535
# 5.05509273782773
# 5.821262127503791
# 8.486592413494984
# 6.102218430095727
# 6.551798353446188
# 6.1625692625714725
# 7.308261640129812
# 5.417226055922605
# 6.244101860468585
# 6.225950634559148
# 6.393624851909399
# 5.651313455188798
# 4.497472763173107
# 7.898964694854552
# 6.32539195221105
# 8.192768126442306
# 7.2192058332552165
# 7.272009723254014
# 8.196004895249926
# 10.396858731608141
# 8.455596820428555
# 7.829596493472229
# 6.938457281831062
# 8.38822360637744
# 5.380211330553097
# 7.377129552306985
# 8.415817075307402
# 7.928585184518427
# 6.385713668097908
# 7.183148687340724
# 6.006269940162941
# 5.347655307685642
# 8.676190167557353
# 5.848670897376107
# 5.8359781501940695
# 5.869020430715972
# 5.456152329194969
# 5.412909444503609
# 3.912118367645777
# 4.171791405817095
# 6.2110117727770175
# 7.184602173975255
# 6.772837704260928
# 8.424639817631041
# 5.792734184388226
# 5.0160558420948185
# 6.4098126928768355
# 7.278804890047309
# 5.661064470442455
# 7.929297786504593
# 7.203980996697957
# 9.096560609518386
# 3.977885631176257
# 4.3824250519185455
# 5.872327388203057
# 4.491366396462975
# 8.860837987478922
# 6.8492660854154055
# 6.005134098682188
# 8.83053470108351
# 6.938889294419237
# 6.186706759318011
# 5.32750174826698
# 7.333716799398738
# 7.28333326161226
# 7.5227447206454965
# 7.709251146446932
# 8.675848075424422
# 5.258041611216743
# 9.855169078901172
# 9.20004913412504
# 9.075876033219489
# 6.190700601431739
# 5.429031194781166
# 6.657367281902269
# 6.925170861495722
# 7.7858213046634335
# 6.253645761472411
# 5.978834571633047
# 6.571623785373478
# 7.584206657106404
# 6.682626434715893
# 5.486240700986009
# 5.147092712719948
# 8.097747419467385
# 7.2443937183301825
# 8.580992143183629
# 8.21777473970725
# 6.077601072302927
# 8.010021843968138
# 7.028662680665685
# 6.329655075333348
# 10.474965653500968
# 10.018971561631194
# 7.475662360407074
# 5.225082286814381
# 5.782392447051694
# 5.6871222978096645
# 7.721412463566437
# 7.076054005693352
# 6.031650235342894
# 9.599471705730405
# 5.855440508900086
# 9.295510061154243
# 8.256213501695871
# 7.465981460156365
# 5.331658564512416
# 8.906405926835424
# 9.459479889846357
# 6.854264246206549
# 8.371615944666434
# 6.6473156081492935
# 8.757527212036686
# 5.0775129419027305
# 7.984044408539464
# 2.722021077219745
# 4.745240898508736
# 4.910622415155441
# 6.520609243198988
# 5.174286911414722
# 5.185713098140921
# 6.230977808120623
# 6.308485668974027
# 4.77031186813517
# 4.48539051465911
# 5.223450632479991
# 8.002958938902239
# 10.455505451370964
# 8.689342069541565
# 5.96423593954831
# 7.124443431212451
# 6.4976058315064105
# 6.285477722788426
# 6.664515982637879
# 6.9157581345813215
# 3.880701626027509
# 5.571109066173433
# 6.436207153118411
# 10.076560499482635
# 7.45563119856827
# 8.152968547897606
# 6.334608974207552
# 8.658493769091862
# 6.926413002659212
# 7.738620930153084
# 6.762740270166582
# 7.328073922260165
# 5.786440930322486
# 9.244615530895187
# 5.777513540346276
# 5.076913273259405
# 6.740510816943254
# 9.309687250361039
# 5.47531054989622
# 6.228370461015725
# 6.884378809729989
# 4.513979057096558
# 4.436677434898357
# 8.187797576554363
# 6.613276886505437
# 4.909533862680956
# 6.029541181800301
# 5.661022620345479
# 6.511893320665924
# 6.794861554443552
# 3.2774701115881038
# 8.501022141058286
# 6.610733408181065
# 5.542452534292065
# 7.8264954185903886
# 4.948265963661922
# 6.028563562217897
# 4.675169276651356
# 7.6165822916244625
# 8.290348022588542
# 7.076125327067639
# 6.2163939115024105
# 4.58641919204597
# 5.81393273498086
# 6.8476608217084065
# 5.6382507571459115
# 5.817611129098285
# 4.81674498706877
# 5.3849960585898
# 4.300171191258864
# 6.91490227979764
# 6.574715367639577
# 6.641762276114232
# 5.959087636575745
# 5.614000110332544
# 6.053127889769148
# 5.860543801224337
# 6.729785015906785
# 9.249474366540921
# 6.216215766959406
# 5.612118947815827
# 6.1260976626106025
# 5.761582512457403
# 5.623469800472336
# 7.52750098912124
# 7.5081662404750755
# 7.853553738940377
# 8.171125951520139
# 5.953110536166031
# 4.148445356940213
# 9.454354123550198
# 3.1137381459079805
# 5.987513954072966
# 4.360200899145017
# 7.104236633280382
# 5.064699382578373
# 8.19742141548042
# 6.848700498872609
# 8.76711713838933
# 6.652368464964656
# 8.238918050736611
# 4.871580833274166
# 7.977611133311722
# 6.2974665670364365
# 6.856817686990011
# 7.891269391478001
# 7.079846023141537
# 5.3140943960011215
# 5.765793408662
# 4.913507114565334
# 7.572955659697914
# 5.981439479926719
# 5.826825931770076
# 6.8037846621487645
# 6.144621520867839
# 8.253366901602408
# 7.6776252722331915
# 7.584352037536407
# 5.877124606935043
# 7.564724230435707
# 7.255106390908756
# 4.675668438200629
# 6.130775661671502
# 6.243045662767054
# 8.743230443719524
# 5.870296019318584
# 7.2236202599084836
# 5.116169060325374
# 6.919110019394281
# 9.548695907010723
# 4.146846618712593
# 5.589760297628317
# 6.909378860890731
# 7.046497234282882
# 6.736115153992346
# 7.31857134705217
# 8.391435250185014
# 6.581370207505964
# 6.388634513315963
# 7.391947667784253
# 9.484917117276542
# 7.399955482515106
# 8.058236198181218
# 4.140212565534899
# 6.230609650733136
# 4.679523832630281
# 6.522840442019325
# 8.640418500688519
# 4.562336668570721
# 9.105679159032068
# 6.493064600599537
# 7.83915151709163
# 8.043207347808309
# 9.49329466095907
# 7.371660891837129
# 5.192212114369923
# 8.018685753148164
# 2.494171838826327
# 5.138989345984803
# 5.629136377135411
# 3.344416744855435
# 9.026062422571785
# 8.49363504776281
# 7.176513236614029
# 7.969569421823638
# 7.7958900165978235
# 8.3936112694395
# 4.330744624320489
# 7.873070294402334
# 8.193792563859265
# 6.153343909393612
# 5.337074359047376
# 6.96670922663818
# 7.086230289741136
# 6.79372014104919
# 5.350370575591903
# 8.557677588814162
# 5.627270096923265
# 7.328971010448177
# 7.682741059267713
# 3.9327004706395616
# 7.002330412546605
# 8.380401536332485
# 6.4787746703383275
# 7.848475966970459
# 5.482917895801893
# 8.081319090021289
# 4.794484668106934
# 6.467199407669715
# 8.352362804890587
# 4.550439370733248
# 6.178950520626781
# 5.600770050014482
# 8.269593572921812
# 6.388256745803804
# 6.722434538465046
# 7.222767114204241
# 4.679219565162775
# 6.9484728863535405
# 4.984746374304672
# 5.765347969695726
# 5.834798882435956
# 7.226013414569115
# 5.310709403318606
# 5.7882140402540845
# 6.986047731587048
# 8.577957187165728
# 7.156416791066392
# 8.195903067729848
# 8.652775718371437
# 5.213976109482897
# 5.586819412609658
# 6.755467820898444
# 5.375231299628373
# 5.582375538224102
# 4.425244313029745
# 6.52190681407775
# 5.9960245450347305
# 7.504167642019981
# 9.078430833474878
# 4.619182511449937
# 7.393930493819874
# 4.200147315453381
# 7.152187904145045
# 4.739920974187413
# 4.480088498295709
# 10.325868545111135
# 9.721910550415688
# 5.43804209194807
# 9.353211246916203
# 6.440656803094602
# 4.443695277111002
# 7.474122312382141
# 7.9238688026546775
# 7.628648856981117
# 3.9652373225025044
# 4.7852779996102095
# 7.905588176397565
# 4.771655830074681
# 8.027391366455774
# 5.955704214253272
# 4.033165422310669
# 4.521544739810217
# 7.181134741561474
# 7.252789744671223
# 8.842770689574943
# 6.529973650426242
# 6.201003472038531
# 9.196342869131302
# 5.240901100875193
# 6.075046699361006
# 7.212189804665917
# 5.156434514572759
# 6.506602334056443
# 8.202754315154815
# 5.873100778976155
# 5.542005444097759
# 9.378438210871545
# 7.7772407489731314
# 8.129480251923134
# 7.75332852074825
# 5.4890293676733
# 5.060412528437176
# 5.6368499771919165
# 8.300281509810866
# 6.4614844524922
# 7.909845725560881
# 7.734877277955471
# 8.903531647368807
# 7.702184213030086
# 6.81939241023987
# 4.551855939596621
# 9.411917964985356
# 8.09708039232351
# 7.1362894462566295
# 6.818803686442597
# 3.8292536792233856
# 7.132885155553526
# 5.704649801208706
# 4.0401464111918965
# 5.773682946871753
# 6.861499420172482
# 7.060217381605997
# 4.732504647348501
# 4.456872720333685
# 6.0457483338346405
# 7.3561129735801485
# 5.310596930644575
# 5.833352173600484
# 6.782383546712929
# 5.269282757071
# 3.490057102829465
# 6.966096325074561
# 3.879941488722518
# 6.168504138712372
# 6.156846478980814
# 4.84563368122985
# 6.002019806330243
# 5.182039297071182
# 10.771841135205712
# 5.29419624561044
# 8.057798842759711
# 5.652192846761176
# 6.864680110041392
# 6.511416190873505
# 6.251909226823539
# 6.204856800401741
# 6.87124294199145
# 8.56464107737609
# 4.803145151367296
# 3.8476401093658747
# 5.254365117491968
# 6.691821473359201
# 6.05625912435117
# 8.813016777341286
# 8.629655997436434
# 5.818011423673875
# 8.817377885040951
# 7.13090572105228
# 5.406782119679224
# 6.320380011881536
# 6.210308918535438
# 5.396012795632573
# 5.549076365279503
# 7.177100916533147
# 5.900188971034228
# 6.075834412196219
# 6.18918427325956
# 6.247767455502002
# 7.881027611149999
# 5.260325097039446
# 6.845582448700139
# 4.230404317148155
# 5.717441193126339
# 4.538800018872659
# 8.926950432681618
# 6.700836554301586
# 5.861270236487703
# 3.894688874989002
# 4.490922623285215
# 7.77744475676673
# 7.032002016868751
# 4.338555889490513
# 4.345500839036945
# 9.2720030132724
# 8.532904207484671
# 6.943023030781518
# 6.674079295993353
# 6.247938034029167
# 4.613755494228158
# 7.790557415743761
# 6.20676000442109
# 7.5954511665806015
# 5.893673799988989
# 7.044515041088788
# 5.779618456581322
# 6.604272317712038
# 7.696149234243123
# 5.697134728101524
# 9.529389603865075
# 5.633048595003581
# 6.704671549595267
# 8.573122561716005
# 8.67542014147691
# 7.201000494249854
# 6.9033106038839405
# 6.603507686732334
# 8.534538090228452
# 7.93590661863006
# 8.134400859196795
# 8.951708332414036
# 7.186957708223834
# 5.889548876054807
# 7.026919976477846
# 6.584169070818921
# 6.216396439383017
# 5.893547587109915
# 7.321543899876031
# 7.456372342830164
# 5.4559832443052
# 6.973985466779875
# 8.93489565584273
# 5.380223355852476
# 8.55348613177113
# 7.041979672749567
# 3.8284858195003215
# 7.459689404715478
# 6.168795851253485
# 3.882782220729148
# 5.793211245526429
# 9.149288431269543
# 7.354895380554626
# 6.6694823291420695
# 7.295503875522
# 8.014777506554282
# 8.785476658214886
# 6.063510572559808
# 7.389238407330989
# 7.212605974259749
# 6.659978735557243
# 6.220302957764735
# 8.90600759431354
# 6.894552364576192
# 4.673903819879079
# 2.1425204632942405
# 7.931263658449358
# 5.854512384268645
# 6.271709589455938
# 7.1117659177359105
# 10.191218705631545
# 8.530623039135204
# 6.159948472872587
# 7.596091009971559
# 5.596537220387702
# 7.660788449602333
# 5.266018316913858
# 6.773937473177055
# 6.823942665026618
# 4.922657283340559
# 5.617238886873169
# 3.2383444141767246
# 5.931161700491071
# 8.173358515144658
# 9.498360336798727
# 8.737505229025057
# 5.921437674385669
# 6.489685569844592
# 6.393156514801936
# 6.185730654498679
# 7.961478503712168
# 5.6728349272346765
# 8.678595886942155
# 6.708114897411994
# 4.751068802124106
# 6.3541840601552675
# 7.218530947169898
# 7.965397182571291
# 7.631340282327933
# 6.0256402670360725
# 5.722325874631664
# 9.09570280109842
# 6.539798540496619
# 4.799530595680228
# 5.621879866386128
# 3.5569065478709176
# 4.05677344173818
# 5.705304970624929
# 5.306425241477066
# 5.470155169940574
# 7.655362186678564
# 7.811151103182834
# 4.75302919205669
# 9.337308497632879
# 6.650969671895256
# 6.511685947626769
# 5.312102006463449
# 6.049478675100156
# 9.542911533954223
# 4.878120313966239
# 6.900962522608788
# 5.6863500999542556
# 3.7855054647871578
# 4.196198410388263
# 7.416034266485579
# 3.9160293294926993
# 4.647620755657388
# 7.732823912386893
# 7.551703643034721
# 6.587914045504112
# 4.732886631627975
# 4.72737934937515
# 4.513996266488566
# 6.299467370403668
# 7.46172889796058
# 5.863822977548688
# 7.827204460133883
# 8.915062802255957
# 7.086641545929885
# 4.619950816500645
# 6.628979139567682
# 8.53028839581785
# 5.553604185419595
# 5.513268347858583
# 8.209800215237424
# 4.345980609497368
# 5.573581337524272
# 5.850766214988095
# 9.055018568403657
# 5.778672316251614
# 6.682387870177498
# 8.047210344555069
# 4.5767981310407
# 7.753953864740012
# 5.82779161440477
# 4.579716523876682
# 5.761466338190899
# 6.593273859019777
# 6.860195762327976
# 5.376475323583758
# 6.175934332407844
# 4.4108043136895265
# 4.457001318290706
# 6.381081593114357
# 5.243747322482914
# 9.612067852539525
# 7.074377769563501
# 4.060586191939504
# 5.380589468559802
# 7.553682949256055
# 6.866895356924164
# 4.143426732672019
# 5.319121665845746
# 7.464936849894926
# 7.056851193512734
# 7.364283916328143
# 6.0800021012924725
# 5.215131630486132
# 4.585968828839441
# 7.9243715158031405
# 9.415349306626144
# 6.9155075994220105
# 7.903685830430427
# 5.301515288995997
# 6.46871885519198
# 6.405565237303613
# 7.07745512534883
# 6.616435255171874
# 7.699437308667132
# 8.448942868332624
# 6.9062431405898845
# 3.3111270312527403
# 7.172474304863297
# 8.142883366906652
# 8.590192220536188
# 6.3991691526450465
# 4.3471932914526
# 6.066078879321739
# 4.3252397155229465
# 8.430703557397145
# 7.180795105723528
# 5.731340306508733
# 8.703703972880117
# 7.6762394526336895
# 9.49952858406309
# 5.171705998679623
# 7.959493877498977
# 4.311335204659673
# 9.340856251178614
# 7.592140599985742
# 5.939790754959318
# 4.766389198610286
# 5.690108011454461
# 6.110763779315205
# 6.824249654263702
# 6.474451875554335
# 5.549625227998135
# 8.236178999867516
# 3.951138371640433
# 7.359943152760927
# 6.778583879321448
# 6.4895107156992315
# 7.4451910515028485
# 5.498362208520369
# 5.34538022909789
# 6.065656992642817
# 5.710139149608143
# 6.144532250470611
# 7.580038414351797
# 6.66563598220461
# 6.544578847991599
# 6.846847854492064
# 7.855195413438468
# 7.348230358065023
# 6.508337384192982
# 4.8012146817164005
# 8.464032964792708
# 7.4968092111628515
# 7.350674691831926
# 9.04882310253654
# 7.543219925475899
# 6.427182180401483
# 5.734020331992594
# 5.6755743027570835
# 6.913561777931976
# 7.950007297138251
# 7.966915671991242
# 4.429295199254065
# 7.886863411035295
# 6.055518607745255
# 5.617448916884472
# 7.049079897803902
# 7.681517409304274
# 4.6501697455276805
# 6.826061672311417
# 4.068183798595184
# 7.687868645803315
# 4.835622426564231
# 6.7861203448047105
# 5.644319438604601
# 3.4993035576955296
# 4.401284800930365
# 6.387221305324755
# 5.104820837451129
# 6.022062392219524
# 5.319778661263722
# 4.697414788424361
# 5.785766907296126
# 6.098054762866858
# 6.544296583152786
# 3.7626461001107785
# 6.576836464099275
# 4.832153928272312
# 4.450854402844746
# 8.347017263487425
# 7.594288417287938
# 6.168821903954427
# 5.628760560424495
# 8.73092260004881
# 6.70228102562248
# 5.15169635225028
# 5.007784330902589
# 6.966773121387422
# 5.977965267668733
# 8.049854248644627
# 6.60816396938957
# 4.699076616413016
# 9.291474084948618
# 4.96914758187683
# 4.666943265160683
# 6.374137012206616
# 7.198684459566474
# 5.150924440639788
# 5.759760204973399
# 10.167755751623089
# 7.000206277038886
# 4.8725535626050505
# 5.444670580605306
# 7.239724943802955
# 5.281785259790797
# 6.3855951059637865
# 9.45461572649163
# 7.459708612076911
# 7.392207550828838
# 9.475955227178641
# 5.361626265681275
# 6.475157663456446
# 6.045023419221122
# 5.560337272049569
# 6.117165676053739
# 5.816481920372706
# 5.512832058162527
# 6.056809034732881
# 5.5186621252869745
# 6.986290294035
# 5.067967393902089
# 8.025326284045887
# 7.588660864012294
# 7.1690479663523785
# 5.8119374361711325
# 6.566106305903488
# 6.3123947889258405
# 6.540438997244132
# 4.491409778999887
# 6.656854210046792
# 6.9876627929547075
# 8.666083816385596
# 4.9897473249331785
# 4.721819592497099
# 7.975183175263966
# 4.231726864420342
# 8.683345730350013
# 8.274560299321598
# 7.371815355688737
# 4.224030987180658
# 6.2608071742576925
# 6.93387346617174
# 7.330887705407253
# 5.375960057981008
# 8.091660597444601
# 7.280653479932107
# 7.2658772509530305
# 6.164854497421536
# 7.082232470089938
# 3.285719713876367
# 7.096421465843712
# 8.986685575512212
# 7.496149896028287
# 7.659359197766543
# 8.313946352159073
# 6.201175821050619
# 7.977829742834953
# 6.596729542568579
# 8.525881338285089
# 5.468530991059543
# 5.5254006819713615
# 2.9649503396381434
# 5.106350354193651
# 5.839712421170852
# 6.424855154762039
# 7.17338607862472
# 7.821849210128791
# 4.506131407098872
# 6.664531886084542
# 5.025243976703746
# 4.504861904794525
# 6.986354731896211
# 6.652454734859143
# 7.2400869862258155
# 7.369638962405151
# 5.776562231306094
# 8.1415352908765
# 5.122264037340094
# 4.91660427237842
# 7.097288869393606
# 6.822035252258921
# 5.285313553473472
# 5.250872404019848
# 7.069820303177764
# 6.875273025438016
# 4.942692866003029
# 5.535506655689188
# 5.133780382668249
# 3.3202367299368
# 6.857659106164045
# 8.237550773356752
# 6.041576549124379
# 5.04192507827844
# 5.188269352607173
# 5.1870671512603845
# 5.721904211583663
# 4.178417579174154
# 5.919959907012098
# 5.638086204227395
# 7.809792738731225
# 7.305882930000799
# 5.926230472644339
# 7.21392401415147
# 4.856988255493614
# 4.605746424810407
# 6.358733640379807
# 6.653260692522582
# 6.289744311978907
# 8.5339275144811
# 7.530982822252614
# 8.052442073137883
# 6.998798667331435
# 4.934762327384739
# 5.4029850103859305
# 6.996687438162066
# 5.165558078066532
# 5.313095065967943
# 7.1459978501220425
# 5.35414451573895
# 7.943293955086206
# 6.178596716043883
# 6.240763827020651
# 6.8768986461460795
# 6.29794471881485
# 6.919972141481907
# 5.123745308390788
# 2.4182726518630293
# 4.3806481002651125
# 5.816984345170073
# 7.235667167321136
# 9.738008439198078
# 5.610356360066764
# 5.518879915272017
# 7.005766801859209
# 6.832440850293202
# 6.883537143037069
# 6.116440447342046
# 3.5289701586837086
# 6.795995390522271
# 6.428656151219235
# 4.116550026783546
# 7.372153978481003
# 7.594605548055837
# 7.337004883819647
# 5.889649209393689
# 6.83139245203043
# 5.153152364870991
# 4.421775154391
# 6.351563947793734
# 4.246795024956253
# 6.299796227920212
# 6.4220406604798255
# 5.273964554481822
# 9.411311479190033
# 5.60203631347381
# 6.818327702534305
# 6.213596274710704
# 7.909228110857711
# 5.9981960253071644
# 4.599412628567759
# 7.122368763628501
# 5.227804592046441
# 5.734461794836913
# 5.791226464092223
# 5.980345973750934
# 5.860973673921069
# 6.688462561854642
# 5.480253477574606
# 7.152470835017195
# 4.595932886918021
# 4.802972405061388
# 5.8828426384245756
# 7.956543960355781
# 6.458722507721718
# 5.808656084163593
# 6.439564416187585
# 4.685100939933193
# 3.9404514051376975
# 5.018511213803058
# 4.926820095012085
# 9.382580452149508
# 9.367073302961591
# 4.675662543986048
# 9.132146534483615
# 5.431160593191913
# 8.967352649705518
# 7.157970102511053
# 5.01125820962578
# 8.982503003708056
# 8.922168240069865
# 4.908827287393719
# 6.98847026102848
# 3.59455267056009
# 5.907405132381223
# 5.9180928921852125
# 5.8865090458171725
# 8.917669644906141
# 4.496176001042483
# 6.164192868837851
# 7.632229635050274
# 4.527136539234055
# 5.174790045276355
# 8.172835781167658
# 8.517450231728512
# 5.850088362685106
# 7.786258387671923
# 8.835150933108515
# 5.889228859652209
# 7.687473083553838
# 5.865791864177935
# 4.470161647083923
# 6.505424403419375
# 6.133330754099902
# 5.110071478987965
# 5.991079355927273
# 6.159796465143172
# 6.918022847934865
# 8.059254165723432
# 8.061085029160502
# 6.370207344490622
# 5.679524073431896
# 8.509807028578763
# 6.350464590938057
# 5.604337984740622
# 6.755242336582289
# 3.761306021920646
# 5.795474149113692
# 5.693886267939374
# 5.315606276160969
# 7.07008223628346
# 8.116312295894843
# 9.03883316310025
# 5.75642743497013
# 6.075824835642986
# 5.480424428639404
# 7.307185780426207
# 3.6987234428428994
# 5.9162137979277745
# 6.937226752250159
# 5.565325765226668
# 5.85652713309959
# 7.987059787047242
# 6.41482904647247
# 8.292022732337797
# 8.95601279164011
# 7.296010049844971
# 6.063846396244784
# 8.872472966398679
# 2.7102313385378896
# 4.172527472389504
# 7.655528995693437
# 10.21139668556451
# 7.523805494129733
# 6.777145479789535
# 5.8002889800101665
# 7.334313578307611
# 8.237143708112827
# 7.623114315749358
# 6.594227149095567
# 8.05025833049088
# 7.2650663098851895
# 7.956137122570105
# 5.098867193769773
# 6.4664119874968655
# 6.6707802664917955
# 4.6989043060339615
# 4.865429883188031
# 5.561207387503464
# 8.062445178723403
# 6.206466437841258
# 6.694945677536545
# 6.962624786346553
# 7.446747132475661
# 7.251705762936483
# 6.60122137367491
# 6.292380107981805
# 8.141803791266438
# 5.760674482463992
# 8.540200596771104
# 5.643779104641833
# 6.0744979450468675
# 7.56247734640293
# 10.047931927232465
# 3.595720379488328
# 7.79871178232619
# 7.208949439027773
# 5.819962796870646
# 5.310669119862309
# 7.141984017492971
# 4.9875484192759245
# 6.726501984774031
# 5.5042747113987875
# 5.819937936972229
# 8.11372861562711
# 4.7523316167826195
# 6.449285954998332
# 7.217793484305915
# 6.887058195798088
# 5.612504092265231
# 7.047935072964364
# 4.955439729992757
# 5.769598265639173
# 8.88604524312319
# 7.4590657895181245
# 6.504142234137249
# 7.174913706615639
# 5.290700204889068
# 6.921956043050087
# 5.822959929482026
# 5.630068738682355
# 6.314151167742367
# 5.59797686085837
# 6.711743581601497
# 7.124757540671653
# 6.090725891589604
# 2.2224230650466357
# 5.197105397105084
# 4.877511408814475
# 7.055441459563218
# 5.405545026691714
# 5.7487144973906235
# 7.759600772927083
# 5.329190091830964
# 6.8042957890023645
# 5.573295220613212
# 5.793425291243358
# 4.754664117774684
# 5.718073744815441
# 7.261559420282963
# 5.052418255257736
# 5.42670651692195
# 9.784949476386267
# 6.88505272258035
# 7.007600993258723
# 8.063300277914301
# 8.307445636084948
# 5.59254593818498
# 8.103001778804744
# 8.509721578648417
# 3.3965143877869357
# 7.789485999756748
# 5.353709244960645
# 8.48828138694648
# 5.299083387528963
# 7.410470120943252
# 3.860722964322612
# 8.17330123967671
# 6.61020464385666
# 8.43696209324632
# 5.42523144787701
# 6.81983120043988
# 8.778615386889324
# 6.4613635154057265
# 7.14448606762397
# 7.54899805862237
# 4.171922221070349
# 5.718353839354402
# 8.206816523538789
# 3.4285619478455827
# 8.1771162896863
# 5.616923977801794
# 9.582907992993315
# 7.155314526055635
# 5.299209434229295
# 7.969197935150531
# 8.649849336118217
# 7.406285553666899
# 5.8311245767738455
# 8.657417469063768
# 5.106632233470695
# 8.107298989282992
# 2.887510555743921
# 6.67645262813497
# 5.6627148899209665
# 4.441428665352898
# 3.2791407480678063
# 8.575724434288603
# 4.200839686403988
# 8.080030638413014
# 5.331022453061091
# 3.5694289564049484
# 5.820769095075995
# 7.345782104877243
# 5.15245128507544
# 6.890366276696399
# 7.534691372991379
# 8.739548728962692
# 6.594877680575705
# 8.248613693747684
# 7.773913493686386
# 6.361452236436528
# 8.220688032876732
# 7.841090697903812
# 6.250852234114347
# 7.570195346837779
# 6.907561265204313
# 7.322092770254415
# 9.324109823761951
# 5.293613567671152
# 6.88204631374227
# 6.545910561942432
# 7.6823534482994305
# 5.822166213845063
# 5.650372774078626
# 6.403479800108307
# 7.212568597414015
# 5.814342989169168
# 2.5181624516827483
# 5.071773585974556
# 8.621712978358891
# 8.820388309347905
# 9.196215165358943
# 6.010134217580618
# 4.197543525431487
# 6.040913494407126
# 7.5881063849489
# 5.652046733831435
# 7.405026586119631
# 6.900345981018022
# 6.07036037943714
# 7.66450401321427
# 8.343688687183207
# 6.772625907493814
# 7.384561506965008
# 4.31531366733941
# 8.587279628979816
# 5.700506854466337
# 5.207449460028062
# 7.830139079902446
# 5.92430591876002
# 5.458642791932551
# 6.059592782268999
# 4.675940753696876
# 5.442775017379499
# 8.033443505440859
# 8.248640742298365
# 6.598145485344925
# 5.480821463292994
# 7.120722616420904
# 3.6554551888905387
# 8.256488570736973
# 6.39553885735153
# 4.9484389489669685
# 8.730691446438765
# 6.563887931698888
# 5.8606789816061555
# 9.574412260507307
# 5.711924848103604
# 7.622993364776889
# 7.539919253134948
# 5.22877884632574
# 6.290497809962371
# 6.121956876933638
# 3.849918672105939
# 3.553942460808503
# 3.236321382221007
# 5.825306577779246
# 5.010073302283389
# 5.102445338844391
# 5.868886374340324
# 6.505510856235575
# 6.030945306217486
# 5.442944744071992
# 9.396418016917565
# 6.19836118114673
# 4.645193314279552
# 8.502789321510782
# 5.6772923183279005
# 10.702359920096209
# 4.532233337873366
# 4.899427533962252
# 6.216909169740354
# 5.967734530366572
# 4.741036759876337
# 8.710909830269516
# 8.553164973310555
# 5.989398482615365
# 8.01445644728177
# 8.633251152118044
# 6.485576853919349
# 5.495454678739138
# 8.422749611441873
# 8.189178503204875
# 4.620051609852417
# 8.624073664193554
# 4.969819436986591
# 7.068589523240631
# 5.275912228753822
# 6.746127417556941
# 6.673458787944594
# 9.848220007575861
# 4.067176800602017
# 5.344146243986163
# 5.801903300682109
# 6.993311341430232
# 6.032005106592595
# 3.2030491287204157
# 7.605496116909098
# 8.502181035240504
# 7.148901721755281
# 5.8153254206998515
# 6.807032063812014
# 8.091764326522906
# 7.246256352715333
# 5.6998080011915695
# 6.623012788532694
# 8.047012069587865
# 8.246712394058138
# 6.388513805877629
# 9.719806320735927
# 8.552079786908743
# 7.291864092598087
# 5.906812410079653
# 5.952334356276359
# 6.800850711828037
# 6.334537132946459
# 9.05057043355691
# 5.094456533343755
# 7.25856168664544
# 3.497280946802083
# 7.065737551469033
# 7.8078620069593825
# 5.61281656572705
# 5.431973690832152
# 8.034994998319506
# 8.292479536175243
# 3.5607613053865914
# 4.911820463941951
# 6.361274259401498
# 4.3729839498188685
# 7.593091874688163
# 5.34100773272843
# 6.391463588570729
# 8.142143745433067
# 7.051456624384117
# 9.416560516489552
# 8.596643493567473
# 4.9416691648381095
# 7.389374838847751
# 6.729361165009172
# 8.280752773157172
# 7.285047198844852
# 5.750375365919368
# 7.214115098924582
# 5.946470751427479
# 5.530567332464462
# 6.33299472973209
# 6.8731611983907825
# 8.450359312347764
# 5.7550120104348705
# 3.624989210326767
# 6.204425529534351
# 6.884548029125915
# 6.773561962268291
# 6.119410169527697
# 7.9244188815467425
# 6.968498259458042
# 7.404517954085499
# 3.744558852044749
# 6.239521694728252
# 6.2912717168099
# 9.025879975184825
# 6.34068202299383
# 5.509773649207866
# 5.421703621260718
# 7.968851034393816
# 5.62930888596785
# 5.220591134677189
# 7.875077294824533
# 7.087917824148642
# 6.1457968637971705
# 4.5085901416057625
# 7.331389659832417
# 7.740398969836858
# 5.070082241097119
# 7.047240006383803
# 6.34896570656663
# 5.173904846671279
# 5.833756758278266
# 6.429398704722262
# 4.522482268901936
# 7.356231662697604
# 5.434489751893075
# 5.4942721810755994
# 7.258369988425819
# 5.82088918910763
# 6.17674576949486
# 6.341661892071381
# 5.337273809663407
# 5.723062725290608
# 6.4734364798090755
# 6.476786580339626
# 7.290548321099722
# 7.356922554519474
# 8.328004915186714
# 4.240437942421004
# 7.869420334931838
# 5.989190604156143
# 7.4874070975246
# 7.009133723354793
# 5.634164652796928
# 8.780154026078042
# 7.641814526532746
# 7.131070231888965
# 9.785139586287615
# 5.038598385144944
# 6.5376214394755845
# 7.343186243103114
# 4.899475832652182
# 5.504051291316706
# 7.995031583393145
# 5.755410951099059
# 7.807828479375389
# 5.55560963595839
# 9.530128368277666
# 2.986036192891856
# 8.0129480366265
# 6.876339118517934
# 6.165441167572666
# 3.610228778649956
# 7.028501435916162
# 5.604694365785193
# 3.5752969626591407
# 6.748510180607689
# 9.660374705607108
# 7.742006888852183
# 2.9187635396145972
# 5.707465387861096
# 8.157082151495718
# 4.059844767409246
# 5.34265061477373
# 5.707939641472617
# 8.886779595593993
# 6.774714929611823
# 6.549969272569128
# 5.124908575907765
# 4.846352187766097
# 6.656032824200144
# 6.379709272059998
# 4.674333297748296
# 6.851049173865555
# 6.586075202032085
# 6.03764540932899
# 8.288756946922351
# 6.481460166148834
# 6.142935902806467
# 8.196755812402115
# 6.273618079262067
# 5.897774439507011
# 4.744816611980996
# 6.5909544442833425
# 7.898653942853785
# 5.874557015844629
# 4.506034044559657
# 8.016396926167781
# 8.075428803712487
# 7.377430787492067
# 6.644159758076812
# 7.130156306017631
# 4.174776668620901
# 5.626775359216891
# 7.513377165219908
# 7.007489582926678
# 7.853821569917121
# 8.800777302184384
# 4.647294615616723
# 7.225358253928523
# 6.112445738723285
# 5.830290118515181
# 10.207778571196696
# 4.144639372937965
# 6.1455954605243654
# 6.571504565619966
# 3.541381813605536
# 5.028333082974751
# 6.5732650152071175
# 4.407027040459895
# 7.930182265015881
# 7.3694320834551785
# 4.1191735015986755
# 6.154465477248585
# 7.0632828506593315
# 4.436345112884069
# 4.133811673051616
# 5.063677968203989
# 10.53120691953875
# 8.141507120645352
# 5.5871078295545304
# 4.503353301797565
# 5.262019240765097
# 8.783527130600616
# 9.550649900346839
# 5.282187546619461
# 6.1066409659372205
# 8.405476040006395
# 4.85909276494859
# 7.968493283719413
# 4.48978898754553
# 7.921633084907549
# 5.223905962461161
# 5.531864121060094
# 9.441704370571017
# 7.99098910654646
# 5.882972922123642
# 8.470399974799523
# 1.4025072035369401
# 7.218766780245698
# 5.061067612012179
# 9.881243293855913
# 10.596063308526192
# 6.546035075351439
# 5.951831066776389
# 6.602010209910554
# 5.567578827415476
# 5.308349381763303
# 6.851852909006207
# 6.699912362163531
# 6.935155061757766
# 5.551165813162692
# 5.099271501715476
# 5.084651093969516
# 7.657925536045581
# 6.619423201621065
# 6.8022892729275295
# 7.012001087834606
# 6.413271720253677
# 6.662685803072728
# 8.443718331429922
# 7.665374054803435
# 6.241463927543074
# 5.7917191833321775
# 8.04092060162991
# 6.999156216694995
# 6.038016976245282
# 4.56297687256146
# 9.041064163531066
# 4.80942800481418
# 6.9266402365101
# 9.23786203726552
# 5.988167227964725
# 6.431784041051978
# 7.780591653123316
# 4.71029649165272
# 3.9952987485196916
# 5.964343057119229
# 6.621056877775881
# 6.604090214649271
# 8.625803062882014
# 5.081148683050302
# 6.284433712228953
# 8.760902344252498
# 6.083232965195946
# 9.480463506493612
# 6.148555326710342
# 5.4589382648921045
# 6.441253686104392
# 6.889387861030974
# 5.882680981096854
# 7.097208812845805
# 6.276235609136963
# 8.404225859355593
# 7.261838933318327
# 6.5161426356068315
# 6.025239761388985
# 7.704262279691771
# 6.546752896681967
# 5.82128740628131
# 5.415289438011043
# 7.54909497279203
# 5.7925472947145575
# 6.050116715582989
# 7.329886140296625
# 8.106346680559515
# 7.39272941759465
# 7.779144254534955
# 7.564366190991733
# 7.091875873164978
# 9.238838212933103
# 4.8613259881154445
# 2.7104344183031213
# 9.403363125752087
# 9.471210427832666
# 5.013713983542958
# 8.4289462787227
# 8.048804571732372
# 7.461835360872845
# 7.254796181677502
# 5.383049951249743
# 6.693975234108693
# 7.021951870857089
# 6.60460589034665
# 6.4179040352742645
# 8.450587123012012
# 8.023528804050555
# 7.811364786387197
# 7.898578912145378
# 6.843988518542226
# 8.24899706826856
# 4.702825442871369
# 6.604336427314484
# 7.5620741976719525
# 7.315170620678677
# 7.061529319600709
# 7.890631387050995
# 8.66156302978597
# 4.904687823830417
# 6.950538763102944
# 5.416503218934029
# 8.10505876996599
# 7.585981310952161
# 5.044499067849235
# 6.489983210062049
# 4.248297011858957
# 7.924790010681165
# 5.696260105724793
# 4.804685507185913
# 5.981580024897625
# 7.375782258682335
# 6.9303498960965815
# 5.766339745317852
# 6.342583480467598
# 6.062349657658508
# 5.098879690698267
# 6.490339031101299
# 7.377510160764542
# 6.476087114775067
# 9.574620237895301
# 5.606322959950124
# 6.437172032816701
# 7.229145741337851
# 7.161051697543903
# 6.116159844828475
# 6.41867501724462
# 6.3750113742083006
# 7.524896021669141
# 5.457647880321032
# 2.8493867529190773
# 5.9853295270399505
# 9.03177100186948
# 7.701921786541731
# 4.147053934880963
# 7.51264901635251
# 6.812648251686306
# 5.9375996162861435
# 4.88281946824976
# 5.2796142986195225
# 5.660097380591928
# 9.252876728318665
# 7.460157619944997
# 5.435620513153321
# 5.686997214885484
# 5.850234959075339
# 6.523519063082865
# 6.281400608978679
# 6.6459067371167
# 3.5025252880114244
# 7.700435649516356
# 5.659802577287877
# 7.860273605317536
# 9.794109683655833
# 4.3209961823967
# 6.647645520863795
# 5.869883801975763
# 7.0922191759721
# 3.3389794943231115
# 5.962641485047976
# 5.272066610853686
# 8.94054307051568
# 9.288953703205681
# 6.07081839099042
# 4.779115701581606
# 5.242109168097334
# 6.5585806696997135
# 4.39799776493686
# 7.278587862978329
# 6.205596153551943
# 7.03448908142719
# 7.091592587604706
# 8.569124297030964
# 7.452534706363611
# 6.939437882665734
# 6.873867820781548
# 3.532599383345834
# 6.769490710476727
# 7.418212380189232
# 6.3181684492333785
# 8.997235446912452
# 4.2719034089451196
# 5.390209897516824
# 5.5471597697895785
# 6.5138989278833614
# 5.530275508799853
# 4.639176521273331
# 5.966324565568488
# 8.022189623241045
# 7.631279346343263
# 5.457625933717496
# 5.939979287632137
# 5.3335450451587745
# 4.607809276563819
# 7.140465424431012
# 4.578326903174844
# 7.494284383264404
# 9.227963942363651
# 7.063521621767242
# 7.434143975499938
# 7.391421223290863
# 5.766997185374737
# 7.0549695320136845
# 6.9685491485770275
# 5.561163851985823
# 2.725527243132308
# 4.928122969905022
# 5.086874139901618
# 7.251503869396689
# 4.281639497675218
# 9.306370985176311
# 8.943848807554255
# 8.07826974679139
# 5.7348857905311625
# 3.382161004959668
# 7.748275599007068
# 5.378174221308103
# 7.681315497020631
# 7.401843354513981
# 5.8399264487467635
# 4.669761787315293
# 6.78078102785035
# 4.145453340867375
# 6.921692238932163
# 7.205240702911591
# 5.510720851427738
# 4.245297027538364
# 8.942401838731548
# 5.697790738915697
# 6.189078080365614
# 8.137140779749583
# 5.647540111774637
# 5.357747566636164
# 9.515192399787399
# 5.40100367967492
# 8.325219300796741
# 6.729515072066401
# 6.697848690723954
# 5.740204853255547
# 6.200642501600297
# 9.180707390052984
# 7.782803318434433
# 4.455918611769053
# 7.074421902258088
# 7.458143786943391
# 7.650053439992199
# 6.384806740355827
# 5.225915019859786
# 5.285012770012925
# 3.04912058808201
# 8.950327379885753
# 2.5561055269257436
# 6.137835393771139
# 3.842710954075028
# 5.623355564981514
# 7.364295625204983
# 3.0701623886156355
# 7.028903083398881
# 7.807232843445818
# 5.874129914013564
# 10.609046693735026
# 3.1325131063663063
# 3.9306157010232603
# 6.045267561358116
# 6.075707046849618
# 6.671706767601393
# 7.892424193902056
# 4.616094526998534
# 4.462761152792913
# 5.458258510101256
# 8.046411765333183
# 7.714207150027747
# 6.395336852268681
# 5.736883820363378
# 6.270814488107049
# 7.04309222339659
# 6.648462975967102
# 4.387556775951503
# 4.282719957716337
# 6.111979472607298
# 7.5873375600932205
# 7.111223128014237
# 3.817162194185456
# 6.606633001391763
# 5.327569076601687
# 3.3651534694456924
# 5.6803437105232115
# 4.60501730063872
# 6.085236341359057
# 7.118957553867055
# 7.185194949599054
# 3.5343555116088727
# 7.362569609734418
# 7.119397197448029
# 5.864490476303017
# 4.5975391135056345
# 5.887804973653335
# 8.916853677306694
# 7.39479971499574
# 7.9587915299758
# 5.016610939592866
# 5.701224473557086
# 4.554555804683645
# 5.5020119618732
# 5.826238199933245
# 5.466341342012861
# 6.858095643768163
# 5.6382409777606
# 6.639100486537939
# 5.646909024640594
# 6.786317772967793
# 5.9299104822020015
# 4.8230739165423175
# 8.08113188148969
# 9.226947928998799
# 7.246354945991791
# 4.247332282038386
# 6.157643537035076
# 6.8673453430948275
# 3.972192205623161
# 5.6957479116460625
# 4.392971572722667
# 4.955430247835593
# 7.009193320436718
# 4.857474002725542
# 6.399384746008498
# 5.956408471906861
# 7.82427919146565
# 5.38869979793488
# 8.77611993918928
# 4.753943751538121
# 4.878319370902684
# 5.72298239693703
# 8.403142300297572
# 7.103314328498042
# 4.90636761481862
# 6.37331524803328
# 5.972548141039346
# 7.174695211988507
# 6.437151816416433
# 6.7946228802917314
# 6.0175877077969435
# 8.483744694980802
# 6.435791580436986
# 5.560478018315905
# 8.09088896453602
# 7.385851154946888
# 5.13545646739529
# 0.5899874330568986
# 7.310632898188025
# 5.846198395394923
# 6.563687156068811
# 8.273334839789545
# 5.070554313341823
# 4.812891650232211
# 4.405828054324548
# 9.805113010930402
# 8.287541364751846
# 7.50743757677137
# 3.6095983777126985
# 4.364327096315341
# 7.553892712718255
# 7.102372955886472
# 6.092300789743263
# 4.471895303705861
# 8.082856552539075
# 9.187863540316052
# 7.157928094879986
# 5.366007114476501
# 8.78628923097465
# 6.7528475948889115
# 8.944836176691274
# 5.962997710464823
# 9.59312985595482
# 5.827277443779093
# 5.507906948020512
# 6.390250289680539
# 7.081197200233836
# 4.972271384404667
# 4.999032730626294
# 5.927888109204267
# 7.03755816601025
# 5.333169837826038
# 8.103781919877072
# 6.339047380084146
# 9.06095815736952
# 7.013531207613021
# 6.906718810446576
# 6.4266161203985375
# 7.77076148013184
# 4.646349048508288
# 6.924311722391923
# 5.0203737635048284
# 6.90264532500399
# 7.9222362466144
# 8.976214277893556
# 8.003513212625547
# 6.5652753602409835
# 4.898727468213876
# 8.793316709408284
# 7.19345268026651
# 7.1922032660902255
# 5.483362485975799
# 6.791239316181988
# 5.5608761646583575
# 8.322949019156043
# 8.359877152778317
# 6.269685206169404
# 5.6222797486410485
# 7.6870229210573875
# 7.477377778896917
# 4.7505800246732655
# 6.062664420751653
# 9.789335018966794
# 6.487885002413569
# 6.852640387224025
# 7.3175075335200335
# 5.661914971418029
# 7.649474263766281
# 7.067121972512528
# 8.187819089519936
# 3.9721046994276556
# 7.031192641584763
# 6.814970289250949
# 4.374413384416231
# 6.100325639466478
# 7.09121338143628
# 6.5751457697023
# 6.462872253216675
# 6.478452596276178
# 5.801863769965768
# 9.508266074585121
# 6.992469814285143
# 6.964639598843352
# 4.50895130817041
# 6.026632139309648
# 5.706553145739598
# 6.45365723929115
# 6.0176759587540865
# 5.573913597301109
# 6.157344869767376
# 4.8756474722215
# 7.392800231783638
# 7.707514315913398
# 7.2471012595810205
# 7.783688511940672
# 7.678432555417187
# 4.573508022149956
# 8.738996874497811
# 7.803644114542546
# 3.6360891946606513
# 5.359943183255791
# 4.65105061482664
# 7.150988761335409
# 5.698978752146001
# 6.5359536529901945
# 9.101763135666314
# 5.06332498418921
# 7.1868284571076995
# 9.240669473158995
# 5.1278442480464985
# 7.951916240787275
# 6.247663289647308
# 5.088749976447993
# 8.771228186078558
# 5.857274773969353
# 6.27571723199831
# 5.967655079396684
# 8.080191775123874
# 7.975132303548151
# 5.387171531801764
# 6.673924799662414
# 7.053168939307623
# 7.963144133695123
# 5.588473200312617
# 8.573713372692342
# 7.721726829364725
# 5.075478436550687
# 7.233935956306551
# 5.4363782355730255
# 7.139780704354612
# 6.503615661635284
# 4.203035034870108
# 1.7060873342734366
# 9.573697864782186
# 6.313876230266075
# 6.661987411631788
# 4.960234074572241
# 5.602389449313159
# 9.752404731622748
# 10.126918584310973
# 3.716974655732359
# 6.586240781068348
# 9.302122884355128
# 6.7968863095304775
# 7.526149684140822
# 6.245692906773199
# 7.2729625077045235
# 8.668335666168055
# 4.6764722738329105
# 5.553950030246575
# 7.660059635883988
# 6.398239255914394
# 5.682130435495373
# 4.864958582006382
# 5.004771883682861
# 5.427338241827297
# 7.185124193668033
# 5.724157363826205
# 6.766906472251648
# 6.7364795227165954
# 7.653418138385668
# 5.26708341903546
# 8.924634459914335
# 3.8614650617160393
# 6.011574480413383
# 5.86289456443677
# 5.315278823266458
# 3.193586472236832
# 8.320105752385068
# 7.744055353331471
# 7.248168629908612
# 5.4105551910830325
# 5.74154956260463
# 5.995634732696835
# 6.140482761091889
# 7.6926425488231995
# 5.758201200794614
# 5.214911141254197
# 6.719933557237502
# 6.563824411539967
# 7.255269208958703
# 8.583132999968747
# 5.889517501068131
# 7.898252454063871
# 6.713215282014032
# 8.03657724507049
# 8.348196024032683
# 5.364064067029169
# 9.469208312286776
# 6.7716468877906415
# 4.779043457296291
# 4.791601023456668
# 8.471531111528565
# 8.144785124033882
# 5.6881784100824815
# 5.939544855670228
# 4.1364067456748455
# 6.062187214310589
# 6.755960140415406
# 8.750268648212936
# 6.086790488326166
# 5.999428971469554
# 6.9340757162628615
# 7.775843512591609
# 8.829201849808051
# 5.450866860120786
# 6.243552442438284
# 6.705431317013641
# 6.100622784827167
# 5.569263453941117
# 6.114544112422649
# 4.672706054698702
# 5.590631455603618
# 4.650414160947543
# 6.518201983119633
# 5.912651450946944
# 5.681761610452664
# 6.523953506254094
# 2.7899279815962164
# 6.024490569397748
# 6.791924693555959
# 7.962204938864502
# 7.413682975393481
# 8.405732856398803
# 4.349864771212292
# 8.069735499663114
# 6.94819097610213
# 5.6945130503075365
# 6.6621449470059115
# 11.188196358432545
# 6.7179902231577415
# 6.620497515605918
# 7.788594021886325
# 5.311261506570965
# 8.60606538746894
# 4.340979162141422
# 6.564765166318204
# 6.402803422096734
# 5.25047198346913
# 4.523223670592774
# 6.308767119685322
# 7.049328365273621
# 8.071298928667819
# 5.342865263816449
# 5.323319168485703
# 8.789192701422698
# 5.798217690671346
# 5.9992168598408755
# 4.030860113359553
# 4.698032287868056
# 8.587953505104746
# 5.597703487954229
# 5.69907640700516
# ...
# 8.390981582737403
# 5.91102633475752
# 6.776191827317718
# 7.6444665944987085
# 7.05026220235413
# 9.212416985421722
# 5.904408700638401
# 9.09630288623703
# 7.534466760505232
# 6.867858133147728
# 6.9852099911184595
# 5.421412182495883
# 6.71859197162267
# 6.136331791917477
# 8.903768247306367
# 5.52449354804247
# 5.828570383973958
# 4.417245851091395
# 5.1941551642447745
# 5.225202087720566
# 8.986838811105864
# 4.483178958760106
# 6.98466614558797
# 8.70145210644007
# 10.656359299333744
# 6.334733814677534
# 6.66804100570352
# 4.750712749870269
# 5.928857175520959
# 9.778479105103537
# 7.807196166390116
# 8.322271996876127
# 7.471755647243967
# 8.102221592176184
# 9.40787862803515
# 5.814887837365232
# 7.60651216010446
# 5.462918280169768
# 3.446444044251356
# 6.897338775770344
# 6.686430627866978
# 6.387442240544189
# 5.541059485645567
# 6.705465220318314
# 7.135232432490904
# 9.442767611722385
# 7.30280253635904
# 7.380904731447113
# 5.376293517844938
# 5.067960765924756
# 6.05574696299232
# 6.590384212313286
# 6.823527255684844
# 5.273094487948803
# 3.1380277202339784
# 5.870508149699264
# 7.90600066481912
# 5.9353993820993995
# 6.388688310784207
# 4.108933849945178
# 6.686553949155524
# 7.114142299044554
# 5.645055116172711
# 7.946605358160446
# 9.673748933830176
# 5.109732602729265
# 6.929481790626851
# 4.718553383656868
# 7.406651011660317
# 7.226289655564792
# 3.6090849015154407
# 6.908250816863706
# 6.201275173533414
# 4.722394194374548
# 6.061934922664694
# 9.592824874394815
# 7.360094720959488
# 5.259455872940228
# 6.0030425276501775
# 3.5969307554058814
# 4.879469745462593
# 9.026252817225515
# 7.875296426339556
# 7.176598523134741
# 7.085034746799003
# 8.625152034984303
# 6.980516262169854
# 6.075042976934839
# 6.362695842433382
# 6.107405783965366
# 6.087662667556954
# 9.044722415916016
# 4.914708447513119
# 5.7424237163861624
# 3.762742300220381
# 8.01640341810388
# 7.01377489870099
# 9.107643997622617
# 5.308021223722875
# 4.752783084364253
# 7.183514846198357
# 5.974762328228672
# 6.9501692070210535
# 5.863857183800856
# 8.65837122768573
# 8.397492672508008
# 6.629129227532931
# 8.07989468005159
# 6.301450231940078
# 6.431332462665173
# 3.2537455219204143
# 7.2604737568744495
# 7.8202870519522145
# 7.571345843525399
# 5.376893508922162
# 6.211763366363331
# 5.78295315625384
# 8.06704900648467
# 8.860115604927929
# 7.697761033032565
# 9.478378912748068
# 7.285856195621662
# 5.038182095213646
# 4.418561719259484
# 5.120133081304749
# 5.819700323212761
# 5.483879782776032
# 6.5815159207912215
# 6.229026255158459
# 6.61200316819882
# 10.16235576061954
# 7.813907546084893
# 6.904317690004838
# 8.092786913757461
# 5.289771564031977
# 5.2257142861218755
# 7.874426104644879
# 6.684030548505756
# 4.785730813740453
# 5.789216488678531
# 5.8857353005228745
# 5.778530970204715
# 9.71748054966749
# 9.681346428761373
# 8.207458305930224
# 6.644797375585445
# 5.6191304867933525
# 4.9480729891536255
# 7.012429988842977
# 7.667121571753806
# 6.652860219035492
# 7.50190831982483
# 6.47160270039584
# 6.0834351195193115
# 4.979501443099254
# 6.006016922784302
# 6.955302394823483
# 5.8749092276227195
# 4.785157480862169
# 6.671935225434667
# 6.955495982325457
# 5.9463425920692154
# 6.466988284365226
# 2.703944199356874
# 7.612640683641582
# 6.932422232840912
# 8.62306705330137
# 6.180524480020371
# 7.600792284805972
# 8.267669759746617
# 6.537043010334787
# 7.016485525140254
# 6.713960207834495
# 4.101427758335188
# 7.080496373011131
# 5.087929705199543
# 5.21247777576081
# 7.286416057453557
# 8.43963629296142
# 7.671184437063895
# 7.373137080882719
# 7.006372004499458
# 7.803110648744207
# 9.026266945900582
# 5.634699349704493
# 5.684009783299072
# 7.596693665213687
# 3.942461193841739
# 6.351587168160221
# 6.891613673858701
# 5.685938330777982
# 3.6236471204938887
# 8.578103297096291
# 5.60056883290096
# 5.667438700820205
# 8.49246949377446
# 2.0699392487305897
# 8.76684926435745
# 5.1658082935874265
# 5.7660615302355005
# 7.232333033182258
# 6.875920856230366
# 7.977080382467239
# 7.24671190407044
# 7.745614587348258
# 11.658063796339746
# 4.108735931818153
# 8.513627636182568
# 8.718927612798316
# 4.853024014825916
# 5.3018503522928215
# 7.2530768353943
# 4.625318112399048
# 5.578386558974719
# 6.8588359737833065
# 5.474468347316018
# 6.158612662440754
# 5.199356019594487
# 5.086509842777237
# 7.207306191333531
# 6.348208760684202
# 6.685072058430082
# 7.556249794624456
# 6.775727503284837
# 5.997297727473797
# 5.179284561504695
# 7.173476481920986
# 9.49156388248429
# 7.820691852627473
# 4.242430141375664
# 3.463112517614336
# 5.397326931947064
# 4.1941138354672525
# 4.5728461692416404
# 2.93672293711017
# 6.849678934171781
# 4.762560629597524
# 4.747813017511357
# 5.504630321434357
# 5.536166533749507
# 6.106459790356887
# 4.399181776967339
# 7.977445379742463
# 6.918509177567007
# 7.120757532125867
# 5.8400745273781
# 8.11167587868725
# 6.7855901332382675
# 7.997308096941911
# 3.9942806524589036
# 6.791007996291707
# 5.495919375859979
# 5.410447960055131
# 7.698758401627975
# 8.55777157746355
# 8.408627953744304
# 6.510158084066833
# 6.0143375652616236
# 8.361312882436465
# 5.0271667792754595
# 9.045554365900474
# 5.920973034017752
# 6.425494831336291
# 5.700186437741187
# 6.552379209791902
# 5.941269414778002
# 6.7304424162429655
# 6.340434016727921
# 2.76617085129174
# 10.210982017972247
# 8.87245025406075
# 4.752419451575449
# 5.567667303475044
# 6.242567385889291
# 7.497054176331316
# 7.20844532220446
# 4.851749328856901
# 10.01369043051168
# 5.905115572590898
# 9.20739654928082
# 5.593888621068352
# 8.085156059964422
# 7.063543564137239
# 5.216599387118862
# 7.381482405318143
# 6.774863067363824
# 7.883159083970863
# 5.336432321918148
# 6.374175451669211
# 7.71329437771918
# 3.7583442391883364
# 4.768636609558154
# 6.560441156988057
# 6.770041040367722
# 6.3566570352234475
# 7.697492501040285
# 6.349612577016541
# 8.033915405727864
# 6.985244697515121
# 4.823187590420796
# 6.742565433994497
# 6.382376695635603
# 5.493368256897671
# 4.2241031018151105
# 4.730217628135379
# 5.228189559253449
# 8.088143779232972
# 6.012726005395738
# 8.333175436297614
# 4.9666662781759126
# 5.441008021066356
# 5.6564871756163475
# 6.063032728324759
# 6.860496754848295
# 7.440110108867756
# 8.383528879988512
# 3.201009440379948
# 4.908663989024246
# 6.650350686854214
# 7.941046658291443
# 7.463373022573255
# 8.18071388130418
# 7.125554029853722
# 7.625269927505893
# 4.643107690542455
# 5.434898532193336
# 5.039254091075748
# 2.9444209202393394
# 5.091380378663786
# 4.948011053639572
# 5.103223954957698
# 7.501423508620928
# 5.35014053715395
# 7.767241773481774
# 4.148963281438077
# 5.519873341302322
# 5.914335275034905
# 8.279242355534556
# 6.592085414346353
# 6.937369733666529
# 4.85410115792436
# 7.777207796295885
# 6.411708842748221
# 3.8698528081445
# 7.550862888835772
# 6.937537220743751
# 5.982463195147417
# 4.89438495588938
# 8.237918460258975
# 7.59055183792054
# 4.912396543287271
# 6.575918382423588
# 5.436159242938608
# 8.833155855474102
# 5.969404115469237
# 5.238446505966749
# 6.137768997692404
# 3.3198491901018166
# 6.271582548856947
# 8.316271138201035
# 7.890928352920021
# 7.222770603508513
# 10.10756139448268
# 6.88436184739761
# 5.133062830486841
# 7.752043849771907
# 6.702086605653687
# 6.559906375834952
# 6.94359484319548
# 5.905780291682272
# 9.303693683065063
# 4.057900659310481
# 7.724137148912339
# 6.699618687871539
# 7.183068295094695
# 5.929632546653636
# 8.770932228900058
# 7.826716494038643
# 5.344774549511172
# 8.179371020160774
# 6.950281873912109
# 5.624613222768117
# 3.9611201943899106
# 7.653164580418441
# 5.413915955643905
# 7.289980041090154
# 8.692694534295597
# 5.283149770834252
# 8.517045096713588
# 4.776742546595953
# 8.724570092520345
# 9.231062884886553
# 7.8496433040222655
# 7.157674261355404
# 7.8357056072940985
# 5.9949006861451695
# 4.508369135488648
# 5.3902233340937356
# 9.932621930877325
# 4.753289892075841
# 7.938827546215321
# 6.333526290752108
# 5.964272012520806
# 9.033456033735348
# 6.639105685645172
# 7.89904080614491
# 10.098552902490717
# 6.186405922108983
# 7.21028649272643
# 7.556797175589315
# 6.016550822398286
# 7.238079471743314
# 8.191976643321063
# 7.673837775364339
# 6.675417620989091
# 4.3308942051475885
# 9.251888609332427
# 5.067855457707682
# 8.251680443378158
# 4.6608472314076534
# 5.054899284841126
# 7.520061448345109
# 8.831415424270055
# 7.4760589778839375
# 7.034875819030848
# 4.459045296516662
# 3.308159255388972
# 5.851366003490485
# 6.731822146546477
# 6.422298047198503
# 9.816248879514468
# 4.186856483292383
# 6.042972824318594
# 9.005534765505072
# 7.4762061354867155
# 4.858583389104628
# 3.1773641403843342
# 5.910793194639516
# 4.982485900082919
# 5.832565214103388
# 9.931029875248097
# 4.981146748959463
# 5.529772904963805
# 7.8703385622255375
# 6.9415122851856275
# 8.748180622079172
# 7.728015329897945
# 5.464733988737754
# 7.272058830380518
# 6.674627962342361
# 3.8599114315907608
# 9.743086927972012
# 4.909807904597675
# 6.338615148731419
# 5.7920771491070795
# 6.6751841352930725
# 6.7895876861532525
# 7.367892639768775
# 5.786448430274988
# 8.123282985156255
# 5.481596657094741
# 5.702358054094663
# 3.9199028258511
# 6.844902827697725
# 8.779917170810139
# 6.127866793362341
# 9.147454991690076
# 4.864693857421861
# 4.463464197291047
# 8.582820460042822
# 6.24631144423606
# 5.0386835441662425
# 6.894262149493961
# 6.9989258080162315
# 7.917863140586835
# 6.0036553225061
# 4.4658735208477385
# 6.089713166511157
# 6.470472837632513
# 8.189627422530673
# 4.2372487509327605
# 5.9351943459604035
# 6.940016367449395
# 5.496588566526884
# 5.279892569691383
# 7.4975270588195455
# 3.0842366900742118
# 5.650061466936862
# 7.386004210506803
# 7.029104878908466
# 6.80328620277922
# 4.039773430056415
# 4.587153366324892
# 8.514006236900322
# 6.358426725582974
# 5.315635507946175
# 6.527771258704555
# 5.767451933113111
# 7.785385727968856
# 4.919312783098173
# 7.752255531704039
# 8.966543754487759
# 7.426767030123462
# 4.648971010377982
# 7.731722961713153
# 5.765560049214664
# 5.715024854242302
# 6.702779713044146
# 6.129138513329563
# 5.803926309276418
# 7.528954345758906
# 6.673291871503459
# 3.632254104741043
# 8.034611355111355
# 8.298554767954442
# 7.402172050628739
# 7.490745862456487
# 6.166489118581783
# 4.705461476361725
# 6.76644256422717
# 6.909190808697584
# 8.992274469519081
# 9.064974628967281
# 6.445993984227334
# 5.804386893002086
# 5.856365532343329
# 6.310358228870983
# 5.03905766684678
# 7.335272616348337
# 7.935124242509298
# 3.724160843610217
# 9.176222632257407
# 6.0570409948928585
# 6.961720230239886
# 5.2423143025189365
# 5.613703809564104
# 5.2537123248251145
# 6.497614695271066
# 5.62789061284225
# 7.0655402516659045
# 4.526315375579973
# 7.166346814704168
# 4.8094309721249715
# 8.01638656689223
# 7.719127820057751
# 3.291015210480065
# 7.76373947871677
# 2.58447263329178
# 4.742308133043073
# 8.04965337957739
# 5.688231957136283
# 8.84102745913511
# 7.561786406464847
# 5.85623838033334
# 5.63988977577483
# 8.754926386350618
# 5.781570604075423
# 3.7097263931454783
# 5.107588264475421
# 6.684972069363152
# 5.321808178855253
# 10.085722323658441
# 5.52959455610948
# 5.563856695748781
# 5.022195203790153
# 7.82197109767565
# 6.0815374249486975
# 7.720903287594542
# 7.045062892232624
# 6.962754940828903
# 4.699107851226739
# 4.2283366121280554
# 4.2556053508988025
# 6.6086679643886965
# 9.956615656710275
# 5.649856093154779
# 8.0373639446087
# 7.2879306833755955
# 6.550767853969141
# 6.135215321875197
# 5.85473523554548
# 5.826990229659064
# 7.408058970457863
# 7.790765508515889
# 5.863988683389587
# 5.843416496184981
# 5.626749795165795
# 8.00023300232818
# 7.818886842365126
# 8.714628370767588
# 5.282345116917667
# 5.573458994976233
# 8.98161952351326
# 8.485904474274149
# 5.013759412962295
# 5.157871800619721
# 6.87992069533966
# 8.362711068549874
# 5.1437057033140965
# 6.630296735823921
# 8.133784286472123
# 6.1956691740130125
# 6.385473348717152
# 8.632065995947572
# 5.873428446888612
# 8.402041320027989
# 6.27556229539857
# 4.871856533442904
# 7.335045475262575
# 5.5754416905021875
# 4.7435940331758
# 9.447128979665269
# 7.128970148290368
# 6.021550266847481
# 6.048881772258144
# 8.7960988483355
# 8.907611591042008
# 5.682742053203853
# 6.896829196114956
# 5.949132347916584
# 7.65184601625074
# 5.9692470604123855
# 3.601808916069434
# 4.952952601793013
# 8.062721963420273
# 5.420103320306381
# 7.678059285251212
# 7.057175035917161
# 5.431271520129586
# 6.267662606862068
# 5.561953993019808
# 5.9295415356245185
# 3.8224116972715168
# 6.3275962452937735
# 5.632075882213673
# 7.2904957167261975
# 7.430955442207583
# 5.648902479034619
# 5.533625770622201
# 6.272587296035471
# 8.14083877126082
# 5.728830762143598
# 5.473685820207381
# 4.848985578360876
# 7.261397276272981
# 6.0630444138342
# 4.991781792471333
# 5.3047107997962275
# 7.503618091807507
# 5.496136294267198
# 7.361509842088832
# 8.052464328347302
# 7.484247509948385
# 8.486491155492978
# 6.59384593443822
# 8.013903048780197
# 7.47684829426866
# 5.69944870395223
# 8.90071796560897
# 9.030865483959577
# 8.29675084852595
# 7.445480715205408
# 7.918489110056925
# 5.997851881286198
# 8.143383406150344
# 4.565205511982448
# 6.010940533722185
# 2.7379926429298065
# 7.100287962118118
# 8.04451088405359
# 8.973776367734446
# 6.177411325028612
# 6.847638380931814
# 6.478394059321884
# 9.212823934944096
# 6.99776652706939
# 9.28170447720069
# 8.367494407049989
# 7.629408811473783
# 5.664954039663405
# 4.87451322902491
# 6.633724607307038
# 6.646106323231051
# 4.754442852904341
# 8.123806714685898
# 6.775750510097374
# 7.38112464569501
# 9.048132938925168
# 5.335530795338542
# 3.375800440288702
# 5.620847104285339
# 9.094948684683718
# 6.512627831539817
# 6.2155319069153885
# 5.724936270718958
# 5.644182063711623
# 5.762110958124603
# 8.069414053800628
# 10.386371616059364
# 5.236184090916973
# 5.695814225759098
# 5.6632758724493035
# 8.886577919635535
# 7.637593125998916
# 6.114301767943017
# 5.746280916618094
# 8.843771523517882
# 6.561726589812161
# 6.441311075346428
# 3.259100872454245
# 7.693730784906779
# 6.48922555070378
# 6.660189906953844
# 6.654524289920693
# 7.910174240048377
# 3.1511193104703867
# 4.70535959696466
# 9.438239545340931
# 4.6601624334228156
# 5.355433026200301
# 8.376415721811547
# 6.575319720667052
# 6.589066650685164
# 8.885814397391323
# 5.637764585154995
# 5.695275898186135
# 7.6407675870455165
# 6.739533989398322
# 8.04238137746177
# 5.5330749642844355
# 6.798750978744185
# 6.390411123082356
# 5.913160633507877
# 4.5767231110965225
# 5.868908437507592
# 5.691729489795533
# 8.379497914027997
# 7.166546119351013
# 6.226964725833987
# 5.162162343979994
# 6.833985009580094
# 8.62723178785939
# 5.2123028910788305
# 7.180665021212646
# 5.820119116871126
# 6.491722133170052
# 6.2665195601413215
# 7.174699048039092
# 6.265798634091193
# 5.745311672541389
# 4.134675568777218
# 6.830195886107462
# 7.415909584852143
# 6.593807073952752
# 6.390686112594759
# 8.730029154637386
# 8.93141678621529
# 8.107301191448371
# 7.002102319605102
# 6.645583085534189
# 4.91970628637907
# 3.641175663402346
# 8.556268869895725
# 6.671084437012149
# 11.587615165829762
# 5.624292514576552
# 7.140446834703692
# 8.03299671730272
# 5.520745925308887
# 6.095551081298291
# 6.208464846885887
# 5.889679253459427
# 7.098328419463154
# 6.582258491532306
# 3.445163675379501
# 6.665361676869885
# 7.060776672436322
# 6.439023764245373
# 8.970316986352344
# 7.0219325490846405
# 6.535317161015731
# 7.864179474470971
# 9.899720777657452
# 6.285003909148459
# 8.080549822242446
# 9.258358497343359
# 6.1538696701234255
# 4.7412224647109
# 7.157473430600577
# 8.520984210324567
# 6.072010229719659
# 8.143442633945266
# 5.210932878418107
# 6.129475875814971
# 6.2912005732911345
# 5.210724629700065
# 5.996905531882728
# 3.5490963940132865
# 7.539448853922998
# 6.554190998099602
# 8.224708822075373
# 6.365691123590544
# 3.8024781040228994
# 6.978506704156817
# 8.103567843931716
# 6.182418887122701
# 9.52280040566988
# 5.15874007490275
# 6.869412890155576
# 7.39792497733388
# 6.004529556779234
# 4.500502811774748
# 6.199660755909093
# 3.771578773714136
# 5.452316135676764
# 6.2328231185789225
# 8.00126118121191
# 6.91942413017364
# 5.801561612651561
# 5.6736353912347965
# 7.879380093349404
# 4.273118870533673
# 5.229693353995565
# 4.265844854200864
# 7.378454049266744
# 8.771382741854655
# 7.360959804550097
# 7.469289881957503
# 5.712215528000025
# 7.231779341476803
# 5.373521302357549
# 5.6374670634411315
# 6.443544500550621
# 9.188473737015658
# 7.799764607800664
# 6.673664037737879
# 9.064162864796472
# 10.10496280193405
# 6.529926317295337
# 7.074391556483333
# 6.747855431210214
# 5.48279854701881
# 3.6707044013721424
# 7.98444759686891
# 6.659533807452561
# 5.1963215639721225
# 3.7587945181257463
# 5.586751156563646
# 5.488785790996028
# 6.334203947106001
# 3.8852955476702693
# 7.144240087818028
# 7.462106906129147
# 4.546930592918312
# 3.9578798403336597
# 8.021722201567524
# 6.276536458939757
# 7.459462020500339
# 6.6657203144991675
# 6.367659085134144
# 8.052267631028919
# 7.760621370764868
# 7.077068953598822
# 7.179900615831984
# 5.848874869796468
# 7.331498224681581
# 8.830228464836619
# 8.035879532058063
# 3.691697829588543
# 7.1777328749799185
# 7.301008773588672
# 8.19909228367997
# 8.357071051980887
# 7.243435505837162
# 4.642064497834375
# 6.330740063429774
# 5.309466088693896
# 4.7512355400784845
# 8.595259517189332
# 5.804082784103141
# 9.484019320837028
# 5.923016602181734
# 5.428634630125767
# 7.402748595032027
# 6.3821659358529015
# 6.91654920303435
# 5.691233932149209
# 5.691001039740254

# %% [markdown]
# So, we find that the only non-numerical value is the string `ERROR`. We can fix this in two ways. First let's try fixing it by splitting the tables like we've done previously.

# %%
errorTable = smartwatch_steps[smartwatch_steps['Sleep Duration (hours)'] == 'ERROR']
errorTable
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)   Step Count  \
# 2      1860.0        247.803052               97.052954  2826.521994
# 62     3068.0        115.078288               99.928041  1918.372142
# 71     3041.0         64.799778               94.743857  4613.859266
# 81     4499.0         41.709895               96.857347  1413.015778
# 92     2021.0         70.243810               97.171134  2336.583406
# ...       ...               ...                     ...          ...
# 9843   1213.0         52.006299               97.110356   215.187641
# 9901   2269.0         63.369107               96.229029  6656.786482
# 9912   2074.0         75.933666               97.386073  1813.072248
# 9927   3007.0         87.579045               98.768633  3727.161872
# 9951   3104.0         70.335328               98.560133  1997.442874
#
#      Sleep Duration (hours) Activity Level Stress Level
# 2                     ERROR  Highly Active            5
# 62                    ERROR  Highly_Active            4
# 71                    ERROR  Highly_Active           10
# 81                    ERROR  Highly_Active            4
# 92                    ERROR  Highly Active            7
# ...                     ...            ...          ...
# 9843                  ERROR     Seddentary            6
# 9901                  ERROR         Active            4
# 9912                  ERROR      Sedentary           10
# 9927                  ERROR         Active            1
# 9951                  ERROR  Highly_Active            9
#
# [235 rows x 7 columns]

# %% [markdown]
# Observe that we've created a table with the rows with `ERROR` in the sleep duration column. We can now replace with the `ERROR` value with our handy NaN value for doing numerical statistics.

# %%
errorTable['Sleep Duration (hours)'] = np.nan

errorTable
# Out:
# /tmp/ipykernel_37784/2302362292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errorTable['Sleep Duration (hours)'] = np.nan
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)   Step Count  \
# 2      1860.0        247.803052               97.052954  2826.521994
# 62     3068.0        115.078288               99.928041  1918.372142
# 71     3041.0         64.799778               94.743857  4613.859266
# 81     4499.0         41.709895               96.857347  1413.015778
# 92     2021.0         70.243810               97.171134  2336.583406
# ...       ...               ...                     ...          ...
# 9843   1213.0         52.006299               97.110356   215.187641
# 9901   2269.0         63.369107               96.229029  6656.786482
# 9912   2074.0         75.933666               97.386073  1813.072248
# 9927   3007.0         87.579045               98.768633  3727.161872
# 9951   3104.0         70.335328               98.560133  1997.442874
#
#       Sleep Duration (hours) Activity Level Stress Level
# 2                        NaN  Highly Active            5
# 62                       NaN  Highly_Active            4
# 71                       NaN  Highly_Active           10
# 81                       NaN  Highly_Active            4
# 92                       NaN  Highly Active            7
# ...                      ...            ...          ...
# 9843                     NaN     Seddentary            6
# 9901                     NaN         Active            4
# 9912                     NaN      Sedentary           10
# 9927                     NaN         Active            1
# 9951                     NaN  Highly_Active            9
#
# [235 rows x 7 columns]

# %% [markdown]
# Now we could go through and put the tables back together, but another method to do this is to use a built-in function to pandas called `pd.to_numeric()`. Let's try that.

# %%
## create a copy of the table 
smartwatch_sleep = smartwatch_steps

smartwatch_sleep['Sleep Duration (hours)'] = pd.to_numeric(smartwatch_sleep['Sleep Duration (hours)'], errors='coerce')

smartwatch_sleep
# Out:
# /tmp/ipykernel_37784/1089028424.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartwatch_sleep['Sleep Duration (hours)'] = pd.to_numeric(smartwatch_sleep['Sleep Duration (hours)'], errors='coerce')
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1         NaN               NaN               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# 4      2130.0         61.950165               98.583797  15679.067648
# ...       ...               ...                     ...           ...
# 9995   1524.0         78.819386               98.931927   2948.491953
# 9996   4879.0         48.632659               95.773035   4725.623070
# 9997   2624.0         73.834442               97.945874   2571.492060
# 9998   4907.0               NaN               98.401058   3364.788855
# 9999   4113.0         70.063864               98.475606    544.696104
#
#       Sleep Duration (hours) Activity Level Stress Level
# 0                   7.167236  Highly Active            1
# 1                   6.538239  Highly_Active            5
# 2                        NaN  Highly Active            5
# 3                   7.367790          Actve            3
# 4                        NaN  Highly_Active            6
# ...                      ...            ...          ...
# 9995                7.402749         Active            7
# 9996                6.382166      Sedentary            2
# 9997                6.916549      Sedentary            4
# 9998                5.691234         Active            8
# 9999                5.691001          Actve            5
#
# [9357 rows x 7 columns]

# %% [markdown]
# Now we can finish **Question 8** and find the minimum, maximum, and mean of the sleep duration column.

# %%
minSleep = float(smartwatch_sleep['Sleep Duration (hours)'].min())

maxSleep = float(smartwatch_sleep['Sleep Duration (hours)'].max())

meanSleep = float(smartwatch_sleep['Sleep Duration (hours)'].mean())

minSleep, maxSleep, meanSleep
# Out:
# (-0.1944527906201543, 12.140232872862926, 6.504028839732376)

# %%
grader.check('q8')
# Out:
# Question 8 results: All test cases passed!

# %% [markdown]
# **Question 9**: Decide how you want to deal with missing and outlier values in the sleep column. Set your final table equal to the variable `smartwatch_updated_sleep`. Use the space below to explain your decisions.
#
# *Remember to start with the `smartwatch_sleep` table that we just created.*
#
# Notes: Refer to [this article](https://pmc.ncbi.nlm.nih.gov/articles/PMC5548942/) on methods of handling these type of instances in data. Keep in mind, you might find that either there are no missing values or no outliers. That's okay, just indicate that in the written space below and update the table i.e. `smartwatch_updated_sleep = smartwatch_sleep`
#
# ANSWER:
#
# I didn't do anything because I'm not sure if I would consider anything as outliers and I didn't remove null values too because I think it's essential information even without sleep hours. So, basically I didn't change anything.

# %%
## use this space or additional cells to address the missing or outlier data. 


smartwatch_updated_sleep = smartwatch_sleep
smartwatch_updated_sleep
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1         NaN               NaN               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# 4      2130.0         61.950165               98.583797  15679.067648
# ...       ...               ...                     ...           ...
# 9995   1524.0         78.819386               98.931927   2948.491953
# 9996   4879.0         48.632659               95.773035   4725.623070
# 9997   2624.0         73.834442               97.945874   2571.492060
# 9998   4907.0               NaN               98.401058   3364.788855
# 9999   4113.0         70.063864               98.475606    544.696104
#
#       Sleep Duration (hours) Activity Level Stress Level
# 0                   7.167236  Highly Active            1
# 1                   6.538239  Highly_Active            5
# 2                        NaN  Highly Active            5
# 3                   7.367790          Actve            3
# 4                        NaN  Highly_Active            6
# ...                      ...            ...          ...
# 9995                7.402749         Active            7
# 9996                6.382166      Sedentary            2
# 9997                6.916549      Sedentary            4
# 9998                5.691234         Active            8
# 9999                5.691001          Actve            5
#
# [9357 rows x 7 columns]

# %% [markdown]
# We're going to skip the `Activity Level` column for a minute and look at the `Stress Level` column. If we try getting the minimum, we'll find the same error as in the Sleep column where we have mixed data types (strings and numerical values). Let's use the same type of loop to make sure we don't obscure any data by forcing the strings to NaN values.

# %%
for item in smartwatch_updated_sleep['Stress Level'].unique():
    try:
        int(item)
    except:
        print(item)
# Out:
# nan

# %% [markdown]
# **Question 10**:
#
# What might you decide to do to deal with the `Very High` value?
#
# Go ahead and do so below and give a brief case for doing so here. Assign your table to the variable `smartwatch_stress`.
#
# ANSWER:
# I just numbered the string into range from 0 - 5 . But, specifically here, I said Very High is 5.

# %%
## cell to deal with 'Very High' value
smartwatch_updated_sleep['Stress Level'] = smartwatch_updated_sleep['Stress Level'].replace('Very High', 5)

smartwatch_stress = smartwatch_updated_sleep

smartwatch_stress
# Out:
# /tmp/ipykernel_37784/3278198645.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartwatch_updated_sleep['Stress Level'] = smartwatch_updated_sleep['Stress Level'].replace('Very High', 5)
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1         NaN               NaN               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# 4      2130.0         61.950165               98.583797  15679.067648
# ...       ...               ...                     ...           ...
# 9995   1524.0         78.819386               98.931927   2948.491953
# 9996   4879.0         48.632659               95.773035   4725.623070
# 9997   2624.0         73.834442               97.945874   2571.492060
# 9998   4907.0               NaN               98.401058   3364.788855
# 9999   4113.0         70.063864               98.475606    544.696104
#
#       Sleep Duration (hours) Activity Level Stress Level
# 0                   7.167236  Highly Active            1
# 1                   6.538239  Highly_Active            5
# 2                        NaN  Highly Active            5
# 3                   7.367790          Actve            3
# 4                        NaN  Highly_Active            6
# ...                      ...            ...          ...
# 9995                7.402749         Active            7
# 9996                6.382166      Sedentary            2
# 9997                6.916549      Sedentary            4
# 9998                5.691234         Active            8
# 9999                5.691001          Actve            5
#
# [9357 rows x 7 columns]

# %% [markdown]
# Finally, let's go back to the `Activity Level` column and investigate what types of values we find there.

# %%
smartwatch['Activity Level'].unique()
# Out:
# array(['Highly Active', 'Highly_Active', 'Actve', 'Seddentary',
#        'Sedentary', 'Active', nan], dtype=object)

# %% [markdown]
# **Question 12**:
#
# What do you notice? There are several values that could and should be combined because they represent the same information. Let's go ahead and do that. While combining these columns, let's also create a new column `NumActivity` where we give a numerical value to represent the activity level. Assign your final table to the variable `final_table`.
#
# `Highly Active` = `1`
#
# `Active` = `2`
#
# `Sedentary` = `3`

# %%
# highly active 
highlyActive = smartwatch_stress[(smartwatch_stress['Activity Level'] == 'Highly Active') | (smartwatch_stress['Activity Level'] == 'Very Active')]
highlyActive['Activity Level'] = 'Highly Active'  # Reset the text in the column
highlyActive['NumActivity'] = 1  

# active 
active = smartwatch_stress[(smartwatch_stress['Activity Level'] == 'Active') | (smartwatch_stress['Activity Level'] == 'Moderately Active')]
active['Activity Level'] = 'Active'  
active['NumActivity'] = 2  

# sedentary
sedentary = smartwatch_stress[(smartwatch_stress['Activity Level'] == 'Sedentary') | (smartwatch_stress['Activity Level'] == 'Low Active')]
sedentary['Activity Level'] = 'Sedentary' 
sedentary['NumActivity'] = 3  

# final table
final_table = pd.concat([highlyActive, active, sedentary, smartwatch_stress[smartwatch_stress['Activity Level'].isnull()]])

final_table
# Out:
# /tmp/ipykernel_37784/264189393.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highlyActive['Activity Level'] = 'Highly Active'  # Reset the text in the column
# /tmp/ipykernel_37784/264189393.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highlyActive['NumActivity'] = 1
# /tmp/ipykernel_37784/264189393.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   active['Activity Level'] = 'Active'
# /tmp/ipykernel_37784/264189393.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   active['NumActivity'] = 2
# /tmp/ipykernel_37784/264189393.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sedentary['Activity Level'] = 'Sedentary'
# /tmp/ipykernel_37784/264189393.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sedentary['NumActivity'] = 3
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)   Step Count  \
# 0      4174.0         58.939776               98.809650  5450.390578
# 2      1860.0        247.803052               97.052954  2826.521994
# 20     2685.0         74.105003               99.646065  2601.396495
# 24     2515.0         69.424795               99.254951  3306.110412
# 32     1459.0         81.782541               98.188991  1540.728037
# ...       ...               ...                     ...          ...
# 9842   2108.0         71.152455               98.585987  1480.777008
# 9845   4203.0         91.417098               95.383875  1238.788704
# 9867   2674.0         69.075313               99.067026  2759.328767
# 9898   1409.0         79.941705               98.716816   619.353083
# 9991   4289.0         91.381582               95.741838  3930.126338
#
#       Sleep Duration (hours) Activity Level Stress Level  NumActivity
# 0                   7.167236  Highly Active            1          1.0
# 2                        NaN  Highly Active            5          1.0
# 20                  6.751333  Highly Active            9          1.0
# 24                  8.415422  Highly Active            1          1.0
# 32                  7.213771  Highly Active           10          1.0
# ...                      ...            ...          ...          ...
# 9842                8.379498            NaN            9          NaN
# 9845                6.226965            NaN            7          NaN
# 9867                4.919706            NaN            5          NaN
# 9898                8.143443            NaN            8          NaN
# 9991                5.804083            NaN            8          NaN
#
# [4827 rows x 8 columns]

# %% [markdown]
# Let's check to make sure that we no longer have any missing values in each column (besides the Activity Level/NumActivity, Stress Level, and User ID columns). You likely either removed those rows or imputed a value to substitute the missing values.

# %%
final_table.isnull().sum()
# Out:
# User ID                   102
# Heart Rate (BPM)          199
# Blood Oxygen Level (%)    134
# Step Count                  0
# Sleep Duration (hours)    188
# Activity Level            190
# Stress Level               87
# NumActivity               190
# dtype: int64

# %% [markdown]
# Then let's use the info function to make sure each column has the data type we're expecting.

# %%
final_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4827 entries, 0 to 9991
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 4725 non-null   float64
#  1   Heart Rate (BPM)        4628 non-null   float64
#  2   Blood Oxygen Level (%)  4693 non-null   float64
#  3   Step Count              4827 non-null   float64
#  4   Sleep Duration (hours)  4639 non-null   float64
#  5   Activity Level          4637 non-null   object
#  6   Stress Level            4740 non-null   object
#  7   NumActivity             4637 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 339.4+ KB

# %% [markdown]
# **Question 13**:
#
# Let's visualize two of the variables. Let's pick `Heart Rate (BPM)` and then you can select any other numerical variable. We're going to create a scatter plot using matplotlib.pyplot. Example code is:
#
# `plt.scatter(x, y)` where x and y are your columns of data such as df['label']
#
# Also try including a size parameter to make your points smaller to better see patterns. We'll talk more about creating figures in python in a few weeks, but for now let's just look at the broad patterns.
#
# Example of including size parameter:
#
# `plt.scatter(x, y, s=1)` Try changing the `s` parameter to 10, 1, 0.5, and 0.1.
#
# What do you notice?
#
# ANSWER:
#
#
# The plot becomes smaller, so it's easier to read data when decreased but at 10, it just overlaps making it hard to read data. However, decreasing it to 0.1 is also too small for me to understand data.

# %%
plt.scatter(final_table['Heart Rate (BPM)'], final_table['Sleep Duration (hours)'])
plt.title('Heart Rate vs Sleep Duration')
plt.xlabel('Heart Rate (BPM)')
plt.ylabel('Sleep Duration (hours)')
plt.show()

# %%
x = final_table['Heart Rate (BPM)']
y = final_table['Sleep Duration (hours)']

plt.scatter(x, y, s=10) 
plt.title('Heart Rate vs Sleep Duration')
plt.xlabel('Heart Rate (BPM)')
plt.ylabel('Sleep Duration (hours)')
plt.show()

# %%
x = final_table['Heart Rate (BPM)']
y = final_table['Sleep Duration (hours)']

plt.scatter(x, y, s=0.5) 
plt.title('Heart Rate vs Sleep Duration')
plt.xlabel('Heart Rate (BPM)')
plt.ylabel('Sleep Duration (hours)')
plt.show()

# %%
x = final_table['Heart Rate (BPM)']
y = final_table['Sleep Duration (hours)']

plt.scatter(x, y, s=0.1) 
plt.title('Heart Rate vs Sleep Duration')
plt.xlabel('Heart Rate (BPM)')
plt.ylabel('Sleep Duration (hours)')
plt.show()

# %%
x = final_table['Heart Rate (BPM)']
y = final_table['Sleep Duration (hours)']

plt.scatter(x, y, s=1) 
plt.title('Heart Rate vs Sleep Duration')
plt.xlabel('Heart Rate (BPM)')
plt.ylabel('Sleep Duration (hours)')
plt.show()

# %% [markdown]
# **Question 14**:
#
#
# Read in the CSV table where we kept all the NaN values instead of removing or imputing them. Repeat the exact same visualization as above with this data.
#
# Compare the two figures. What do you notice?
#
# ANSWER:
#
# I don't know why outliers aren't present in this csv file but it seems like all the outliers are missing after scale of 120 in y axis.

# %%
nanTable = pd.read_csv('smartwatch_nan_vals.csv')

# %%
plt.scatter(nanTable['Heart Rate (BPM)'], nanTable['Sleep Duration (hours)'], s=1)

# %% [markdown]
# **Question 15**:
#
#
# Does the amount of steps signficantly differ between the different activity level groups?
#
# Hint: Try using a boxplot (`sns.boxplot`) to first visualize the problem. Then you can use scipy.stats to run an ANOVA.

# %%
## Visualization 

sns.boxplot(x='Activity Level', y='Step Count', data=final_table)
plt.show()

# %%
from scipy.stats import f_oneway

## create a table for each activity level group
sed = final_table[final_table['Activity Level'] == 'Sedentary']
act = final_table[final_table['Activity Level'] == 'Active']
hact = final_table[final_table['Activity Level'] == 'Highly Active']

stat, pval = f_oneway(sed['Step Count'], act['Step Count'], hact['Step Count'])


print(f"ANOVA test statistic: {stat:.3f}, p-value: {pval:.3f}")
# Out:
# ANOVA test statistic: 1.338, p-value: 0.262

# %% [markdown]
# Is there significant difference between the groups' step counts?
#
# ANSWER:
#
# No, there isn't significant difference between the groups' step counts.

# %% [markdown]
# **Question 16**
#
# If you were to present your findings from this dataset to a broader audience (such as policymakers, healthcare providers, or the general public), how would you communicate key insights responsibly? What considerations would you take into account to avoid misrepresenting the data or reinforcing biases?
#
# ANSWER:
#
# I would let them know that the data being collected doesn't fully share right information. Moreover, there are many outliers in data including outliers in Heart Rate. I'll highly recommend not to fully trust and get anxious about the information being collected. Moreover, this was one example but many column have missing data and outliers which later is used to make plots which might fasely interpret non-exisiting information.
#
# Moreover, in order to avoid misepresentation, I'll try to clean data in a way where I remove unnecessary informations, null values and outliers which I know aren't in correct order and which aren't very important for data set so that I can have precise representation if not accurate.
